# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as utils
from IPython.display import HTML
import time
from torchvision import models
import torch.nn.functional as F
from scipy import linalg

# %%
dataset = datasets.CIFAR10(root="/home/nsuresh/Deep-Learning/Homework 3/dataset/CIFAR10data", download=False,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=32,
                                         shuffle=True, num_workers=2)

device = torch.device("cuda")

# %%
real_batch = next(iter(dataloader))
plt.figure(figsize=(10,10))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            # _block(in_channels, out_channels, kernel_size, stride, padding)
            self._block(features_d, features_d * 2, 4, 2, 1),
            self._block(features_d * 2, features_d * 4, 4, 2, 1),
            self._block(features_d * 4, features_d * 8, 4, 2, 1),
            # After all _block img output is 4x4 (Conv2d below makes into 1x1)
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.InstanceNorm2d(out_channels, affine=True),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            # Input: N x channels_noise x 1 x 1
            self._block(channels_noise, features_g * 16, 4, 1, 0),  # img: 4x4
            self._block(features_g * 16, features_g * 8, 4, 2, 1),  # img: 8x8
            self._block(features_g * 8, features_g * 4, 4, 2, 1),  # img: 16x16
            self._block(features_g * 4, features_g * 2, 4, 2, 1),  # img: 32x32
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            # Output: N x channels_img x 64 x 64
            nn.Tanh(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
def initialize_weights(model):
    # Initializes weights according to the DCGAN paper
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
class InceptionV3(nn.Module):
    """Pretrained InceptionV3 network returning feature maps"""

    # Index of default block of inception to return,
    # corresponds to output of final average pooling
    DEFAULT_BLOCK_INDEX = 3

    # Maps feature dimensionality to their output blocks indices
    BLOCK_INDEX_BY_DIM = {
        64: 0,
        192: 1,
        768: 2,
        2048: 3
    }

    def __init__(self,
                 output_blocks=[DEFAULT_BLOCK_INDEX],
                 resize_input=True,
                 normalize_input=True,
                 requires_grad=False):
        
        super(InceptionV3, self).__init__()

        self.resize_input = resize_input
        self.normalize_input = normalize_input
        self.output_blocks = sorted(output_blocks)
        self.last_needed_block = max(output_blocks)

        assert self.last_needed_block <= 3, \
            'Last possible output block index is 3'

        self.blocks = nn.ModuleList()

        
        inception = models.inception_v3(pretrained=True)

        # Block 0: input to maxpool1
        block0 = [
            inception.Conv2d_1a_3x3,
            inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2)
        ]
        self.blocks.append(nn.Sequential(*block0))

        # Block 1: maxpool1 to maxpool2
        if self.last_needed_block >= 1:
            block1 = [
                inception.Conv2d_3b_1x1,
                inception.Conv2d_4a_3x3,
                nn.MaxPool2d(kernel_size=3, stride=2)
            ]
            self.blocks.append(nn.Sequential(*block1))

        # Block 2: maxpool2 to aux classifier
        if self.last_needed_block >= 2:
            block2 = [
                inception.Mixed_5b,
                inception.Mixed_5c,
                inception.Mixed_5d,
                inception.Mixed_6a,
                inception.Mixed_6b,
                inception.Mixed_6c,
                inception.Mixed_6d,
                inception.Mixed_6e,
            ]
            self.blocks.append(nn.Sequential(*block2))

        # Block 3: aux classifier to final avgpool
        if self.last_needed_block >= 3:
            block3 = [
                inception.Mixed_7a,
                inception.Mixed_7b,
                inception.Mixed_7c,
                nn.AdaptiveAvgPool2d(output_size=(1, 1))
            ]
            self.blocks.append(nn.Sequential(*block3))

        for param in self.parameters():
            param.requires_grad = requires_grad

    def forward(self, inp):
        outp = []
        x = inp

        if self.resize_input:
            x = F.interpolate(x,
                              size=(299, 299),
                              mode='bilinear',
                              align_corners=False)

        if self.normalize_input:
            x = 2 * x - 1  # Scale from range (0, 1) to range (-1, 1)

        for idx, block in enumerate(self.blocks):
            x = block(x)
            if idx in self.output_blocks:
                outp.append(x)

            if idx == self.last_needed_block:
                break

        return outp
    
block_idx = InceptionV3.BLOCK_INDEX_BY_DIM[2048]
model = InceptionV3([block_idx])
model=model.cuda()

# %%
def calculate_activation_statistics(images, model, batch_size=128, dims=2048, cuda=False):
    model.eval()
    act=np.empty((len(images), dims))
    
    if cuda:
        batch=images.cuda()
    else:
        batch=images
    pred = model(batch)[0]
    if pred.size(2) != 1 or pred.size(3) != 1:
        pred = adaptive_avg_pool2d(pred, output_size=(1, 1))

    act= pred.cpu().data.numpy().reshape(pred.size(0), -1)
    
    mu = np.mean(act, axis=0)
    sigma = np.cov(act, rowvar=False)
    return mu, sigma

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)

    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)

    assert mu1.shape == mu2.shape, \
        'Training and test mean vectors have different lengths'
    assert sigma1.shape == sigma2.shape, \
        'Training and test covariances have different dimensions'

    diff = mu1 - mu2

    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        msg = ('fid calculation produces singular product; '
               'adding %s to diagonal of cov estimates') % eps
        print(msg)
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))

    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real

    tr_covmean = np.trace(covmean)

    return (diff.dot(diff) + np.trace(sigma1) +
            np.trace(sigma2) - 2 * tr_covmean)

def calculate_fretchet(images_real,images_fake,model):
    mu_1,std_1 = calculate_activation_statistics(images_real,model,cuda=True)
    mu_2,std_2 = calculate_activation_statistics(images_fake,model,cuda=True)
    fid_value = calculate_frechet_distance(mu_1, std_1, mu_2, std_2)
    return fid_value

# %%
lr = 5e-5
Z_DIM = 128
num_epochs = 30
WEIGHT_CLIP = 0.01

# %%
gen = Generator(Z_DIM, channels_img = 3, features_g = 64).to(device)
critic = Discriminator(channels_img = 3, features_d = 64).to(device)
initialize_weights(gen)
initialize_weights(critic)

# %%
opt_gen = optim.RMSprop(gen.parameters(), lr = lr)
opt_critic = optim.RMSprop(critic.parameters(), lr = lr)

fixed_noise = torch.randn(32, Z_DIM, 1, 1).to(device)
step = 0

gen.train()
critic.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#   )
# )

# %%
GenLoss = []
DiscLoss = []
img_list = []
fretchet_distances = []
iters = 0

for epoch in range(num_epochs):
    # Target labels not needed! <3 unsupervised
    for batch_idx, (data, _) in enumerate(dataloader):
        data = data.to(device)
        cur_batch_size = data.shape[0]

        # Train Critic: max E[critic(real)] - E[critic(fake)]
        for _ in range(5): # 5 critic iterations
            noise = torch.randn(cur_batch_size, Z_DIM, 1, 1).to(device)
            fake = gen(noise)
            critic_real = critic(data).reshape(-1)
            critic_fake = critic(fake).reshape(-1)
            loss_critic = -(torch.mean(critic_real) - torch.mean(critic_fake))
            critic.zero_grad()
            loss_critic.backward(retain_graph=True)
            opt_critic.step()

            # clip critic weights between -0.01, 0.01
            for p in critic.parameters():
                p.data.clamp_(-WEIGHT_CLIP, WEIGHT_CLIP)

        # Train Generator: max E[critic(gen_fake)] <-> min -E[critic(gen_fake)]
        gen_fake = critic(fake).reshape(-1)
        loss_gen = -torch.mean(gen_fake)
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()

        # Print losses occasionally
        if batch_idx % 100 == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(dataloader)} \
                  Loss Discriminator: {loss_critic:.3f}, loss Generator: {loss_gen:.3f}"
            )
        #saving the losses for every 100 batch
        GenLoss.append(loss_gen.detach().cpu())
        DiscLoss.append(loss_critic.detach().cpu())
        
        # Check how the generator is doing by saving G's output on fixed_noise
        if (iters % 500 == 0) or ((epoch == num_epochs) and (batch_idx == len(dataloader)-1)):
            with torch.no_grad():
                fake = gen(fixed_noise).detach().cpu()
            img_list.append(utils.make_grid(fake, padding=2, normalize=True))
            
        iters += 1
    fretchet_dist = calculate_fretchet(data, fake, model)
    fretchet_distances.append(fretchet_dist)
    print('Fretchet Distance: ', fretchet_dist)
# Out:
# Epoch [0/30] Batch 0/1563                   Loss Discriminator: -0.020, loss Generator: 0.012
# Epoch [0/30] Batch 100/1563                   Loss Discriminator: -1.349, loss Generator: 0.670
# Epoch [0/30] Batch 200/1563                   Loss Discriminator: -1.502, loss Generator: 0.734
# Epoch [0/30] Batch 300/1563                   Loss Discriminator: -1.542, loss Generator: 0.759
# Epoch [0/30] Batch 400/1563                   Loss Discriminator: -1.535, loss Generator: 0.757
# Epoch [0/30] Batch 500/1563                   Loss Discriminator: -1.515, loss Generator: 0.752
# Epoch [0/30] Batch 600/1563                   Loss Discriminator: -1.522, loss Generator: 0.750
# Epoch [0/30] Batch 700/1563                   Loss Discriminator: -1.420, loss Generator: 0.686
# Epoch [0/30] Batch 800/1563                   Loss Discriminator: -1.426, loss Generator: 0.698
# Epoch [0/30] Batch 900/1563                   Loss Discriminator: -1.337, loss Generator: 0.673
# Epoch [0/30] Batch 1000/1563                   Loss Discriminator: -1.387, loss Generator: 0.683
# Epoch [0/30] Batch 1100/1563                   Loss Discriminator: -1.334, loss Generator: 0.654
# Epoch [0/30] Batch 1200/1563                   Loss Discriminator: -1.290, loss Generator: 0.626
# Epoch [0/30] Batch 1300/1563                   Loss Discriminator: -1.208, loss Generator: 0.637
# Epoch [0/30] Batch 1400/1563                   Loss Discriminator: -1.221, loss Generator: 0.636
# Epoch [0/30] Batch 1500/1563                   Loss Discriminator: -1.212, loss Generator: 0.589
# Fretchet Distance:  310.3249799939104
# Epoch [1/30] Batch 0/1563                   Loss Discriminator: -1.037, loss Generator: 0.639
# Epoch [1/30] Batch 100/1563                   Loss Discriminator: -1.061, loss Generator: 0.398
# Epoch [1/30] Batch 200/1563                   Loss Discriminator: -1.049, loss Generator: 0.612
# Epoch [1/30] Batch 300/1563                   Loss Discriminator: -1.085, loss Generator: 0.649
# Epoch [1/30] Batch 400/1563                   Loss Discriminator: -1.014, loss Generator: 0.608
# Epoch [1/30] Batch 500/1563                   Loss Discriminator: -1.163, loss Generator: 0.571
# Epoch [1/30] Batch 600/1563                   Loss Discriminator: -0.960, loss Generator: 0.376
# Epoch [1/30] Batch 700/1563                   Loss Discriminator: -0.917, loss Generator: 0.635
# Epoch [1/30] Batch 800/1563                   Loss Discriminator: -0.939, loss Generator: 0.441
# Epoch [1/30] Batch 900/1563                   Loss Discriminator: -0.834, loss Generator: 0.296
# Epoch [1/30] Batch 1000/1563                   Loss Discriminator: -0.883, loss Generator: 0.484
# Epoch [1/30] Batch 1100/1563                   Loss Discriminator: -1.088, loss Generator: 0.555
# Epoch [1/30] Batch 1200/1563                   Loss Discriminator: -1.132, loss Generator: 0.555
# Epoch [1/30] Batch 1300/1563                   Loss Discriminator: -1.133, loss Generator: 0.593
# Epoch [1/30] Batch 1400/1563                   Loss Discriminator: -0.990, loss Generator: 0.506
# Epoch [1/30] Batch 1500/1563                   Loss Discriminator: -0.995, loss Generator: 0.401
# Fretchet Distance:  299.2170627171173
# Epoch [2/30] Batch 0/1563                   Loss Discriminator: -1.046, loss Generator: 0.457
# Epoch [2/30] Batch 100/1563                   Loss Discriminator: -0.907, loss Generator: 0.643
# Epoch [2/30] Batch 200/1563                   Loss Discriminator: -1.056, loss Generator: 0.477
# Epoch [2/30] Batch 300/1563                   Loss Discriminator: -0.930, loss Generator: 0.334
# Epoch [2/30] Batch 400/1563                   Loss Discriminator: -1.034, loss Generator: 0.431
# Epoch [2/30] Batch 500/1563                   Loss Discriminator: -0.994, loss Generator: 0.624
# Epoch [2/30] Batch 600/1563                   Loss Discriminator: -1.006, loss Generator: 0.618
# Epoch [2/30] Batch 700/1563                   Loss Discriminator: -1.033, loss Generator: 0.454
# Epoch [2/30] Batch 800/1563                   Loss Discriminator: -0.918, loss Generator: 0.514
# Epoch [2/30] Batch 900/1563                   Loss Discriminator: -0.921, loss Generator: 0.428
# Epoch [2/30] Batch 1000/1563                   Loss Discriminator: -0.963, loss Generator: 0.378
# Epoch [2/30] Batch 1100/1563                   Loss Discriminator: -0.924, loss Generator: 0.386
# Epoch [2/30] Batch 1200/1563                   Loss Discriminator: -0.804, loss Generator: 0.363
# Epoch [2/30] Batch 1300/1563                   Loss Discriminator: -0.959, loss Generator: 0.395
# Epoch [2/30] Batch 1400/1563                   Loss Discriminator: -0.855, loss Generator: 0.624
# Epoch [2/30] Batch 1500/1563                   Loss Discriminator: -0.855, loss Generator: 0.619
# Fretchet Distance:  290.3889720842799
# Epoch [3/30] Batch 0/1563                   Loss Discriminator: -1.008, loss Generator: 0.478
# Epoch [3/30] Batch 100/1563                   Loss Discriminator: -0.942, loss Generator: 0.451
# Epoch [3/30] Batch 200/1563                   Loss Discriminator: -0.796, loss Generator: 0.249
# Epoch [3/30] Batch 300/1563                   Loss Discriminator: -0.948, loss Generator: 0.608
# Epoch [3/30] Batch 400/1563                   Loss Discriminator: -0.879, loss Generator: 0.366
# Epoch [3/30] Batch 500/1563                   Loss Discriminator: -0.901, loss Generator: 0.613
# Epoch [3/30] Batch 600/1563                   Loss Discriminator: -0.896, loss Generator: 0.346
# Epoch [3/30] Batch 700/1563                   Loss Discriminator: -0.833, loss Generator: 0.252
# Epoch [3/30] Batch 800/1563                   Loss Discriminator: -0.901, loss Generator: 0.382
# Epoch [3/30] Batch 900/1563                   Loss Discriminator: -0.823, loss Generator: 0.573
# Epoch [3/30] Batch 1000/1563                   Loss Discriminator: -0.872, loss Generator: 0.587
# Epoch [3/30] Batch 1100/1563                   Loss Discriminator: -0.910, loss Generator: 0.598
# Epoch [3/30] Batch 1200/1563                   Loss Discriminator: -0.933, loss Generator: 0.411
# Epoch [3/30] Batch 1300/1563                   Loss Discriminator: -0.819, loss Generator: 0.265
# Epoch [3/30] Batch 1400/1563                   Loss Discriminator: -0.923, loss Generator: 0.373
# Epoch [3/30] Batch 1500/1563                   Loss Discriminator: -0.795, loss Generator: 0.619
# Fretchet Distance:  312.10681916011595
# Epoch [4/30] Batch 0/1563                   Loss Discriminator: -0.900, loss Generator: 0.309
# Epoch [4/30] Batch 100/1563                   Loss Discriminator: -0.772, loss Generator: 0.309
# Epoch [4/30] Batch 200/1563                   Loss Discriminator: -0.764, loss Generator: 0.335
# Epoch [4/30] Batch 300/1563                   Loss Discriminator: -0.858, loss Generator: 0.312
# Epoch [4/30] Batch 400/1563                   Loss Discriminator: -0.937, loss Generator: 0.490
# Epoch [4/30] Batch 500/1563                   Loss Discriminator: -0.690, loss Generator: 0.253
# Epoch [4/30] Batch 600/1563                   Loss Discriminator: -0.745, loss Generator: 0.186
# Epoch [4/30] Batch 700/1563                   Loss Discriminator: -0.637, loss Generator: 0.310
# Epoch [4/30] Batch 800/1563                   Loss Discriminator: -0.679, loss Generator: 0.336
# Epoch [4/30] Batch 900/1563                   Loss Discriminator: -0.770, loss Generator: 0.592
# Epoch [4/30] Batch 1000/1563                   Loss Discriminator: -0.852, loss Generator: 0.553
# Epoch [4/30] Batch 1100/1563                   Loss Discriminator: -0.741, loss Generator: 0.275
# Epoch [4/30] Batch 1200/1563                   Loss Discriminator: -0.769, loss Generator: 0.277
# Epoch [4/30] Batch 1300/1563                   Loss Discriminator: -0.816, loss Generator: 0.284
# Epoch [4/30] Batch 1400/1563                   Loss Discriminator: -0.810, loss Generator: 0.323
# Epoch [4/30] Batch 1500/1563                   Loss Discriminator: -0.757, loss Generator: 0.183
# Fretchet Distance:  311.44737359081313
# Epoch [5/30] Batch 0/1563                   Loss Discriminator: -0.810, loss Generator: 0.518
# Epoch [5/30] Batch 100/1563                   Loss Discriminator: -0.761, loss Generator: 0.239
# Epoch [5/30] Batch 200/1563                   Loss Discriminator: -0.802, loss Generator: 0.557
# Epoch [5/30] Batch 300/1563                   Loss Discriminator: -0.754, loss Generator: 0.265
# Epoch [5/30] Batch 400/1563                   Loss Discriminator: -0.818, loss Generator: 0.242
# Epoch [5/30] Batch 500/1563                   Loss Discriminator: -0.766, loss Generator: 0.454
# Epoch [5/30] Batch 600/1563                   Loss Discriminator: -0.730, loss Generator: 0.152
# Epoch [5/30] Batch 700/1563                   Loss Discriminator: -0.655, loss Generator: 0.567
# Epoch [5/30] Batch 800/1563                   Loss Discriminator: -0.786, loss Generator: 0.520
# Epoch [5/30] Batch 900/1563                   Loss Discriminator: -0.677, loss Generator: 0.184
# Epoch [5/30] Batch 1000/1563                   Loss Discriminator: -0.614, loss Generator: 0.123
# Epoch [5/30] Batch 1100/1563                   Loss Discriminator: -0.651, loss Generator: 0.588
# Epoch [5/30] Batch 1200/1563                   Loss Discriminator: -0.729, loss Generator: 0.580
# Epoch [5/30] Batch 1300/1563                   Loss Discriminator: -0.696, loss Generator: 0.364
# Epoch [5/30] Batch 1400/1563                   Loss Discriminator: -0.681, loss Generator: 0.602
# Epoch [5/30] Batch 1500/1563                   Loss Discriminator: -0.766, loss Generator: 0.204
# Fretchet Distance:  267.7227066469476
# Epoch [6/30] Batch 0/1563                   Loss Discriminator: -0.838, loss Generator: 0.334
# Epoch [6/30] Batch 100/1563                   Loss Discriminator: -0.659, loss Generator: 0.159
# Epoch [6/30] Batch 200/1563                   Loss Discriminator: -0.731, loss Generator: 0.464
# Epoch [6/30] Batch 300/1563                   Loss Discriminator: -0.638, loss Generator: 0.180
# Epoch [6/30] Batch 400/1563                   Loss Discriminator: -0.760, loss Generator: 0.553
# Epoch [6/30] Batch 500/1563                   Loss Discriminator: -0.587, loss Generator: 0.547
# Epoch [6/30] Batch 600/1563                   Loss Discriminator: -0.698, loss Generator: 0.208
# Epoch [6/30] Batch 700/1563                   Loss Discriminator: -0.708, loss Generator: 0.593
# Epoch [6/30] Batch 800/1563                   Loss Discriminator: -0.733, loss Generator: 0.484
# Epoch [6/30] Batch 900/1563                   Loss Discriminator: -0.757, loss Generator: 0.563
# Epoch [6/30] Batch 1000/1563                   Loss Discriminator: -0.711, loss Generator: 0.026
# Epoch [6/30] Batch 1100/1563                   Loss Discriminator: -0.693, loss Generator: 0.579
# Epoch [6/30] Batch 1200/1563                   Loss Discriminator: -0.723, loss Generator: 0.200
# Epoch [6/30] Batch 1300/1563                   Loss Discriminator: -0.687, loss Generator: 0.207
# Epoch [6/30] Batch 1400/1563                   Loss Discriminator: -0.487, loss Generator: 0.088
# Epoch [6/30] Batch 1500/1563                   Loss Discriminator: -0.581, loss Generator: 0.478
# Fretchet Distance:  269.20040914881656
# Epoch [7/30] Batch 0/1563                   Loss Discriminator: -0.670, loss Generator: 0.249
# Epoch [7/30] Batch 100/1563                   Loss Discriminator: -0.678, loss Generator: 0.306
# Epoch [7/30] Batch 200/1563                   Loss Discriminator: -0.618, loss Generator: 0.580
# Epoch [7/30] Batch 300/1563                   Loss Discriminator: -0.772, loss Generator: 0.325
# Epoch [7/30] Batch 400/1563                   Loss Discriminator: -0.580, loss Generator: 0.549
# Epoch [7/30] Batch 500/1563                   Loss Discriminator: -0.616, loss Generator: 0.143
# Epoch [7/30] Batch 600/1563                   Loss Discriminator: -0.668, loss Generator: 0.567
# Epoch [7/30] Batch 700/1563                   Loss Discriminator: -0.716, loss Generator: 0.374
# Epoch [7/30] Batch 800/1563                   Loss Discriminator: -0.718, loss Generator: 0.534
# Epoch [7/30] Batch 900/1563                   Loss Discriminator: -0.618, loss Generator: 0.029
# Epoch [7/30] Batch 1000/1563                   Loss Discriminator: -0.671, loss Generator: 0.221
# Epoch [7/30] Batch 1100/1563                   Loss Discriminator: -0.595, loss Generator: 0.545
# Epoch [7/30] Batch 1200/1563                   Loss Discriminator: -0.651, loss Generator: 0.575
# Epoch [7/30] Batch 1300/1563                   Loss Discriminator: -0.549, loss Generator: 0.518
# Epoch [7/30] Batch 1400/1563                   Loss Discriminator: -0.652, loss Generator: 0.472
# Epoch [7/30] Batch 1500/1563                   Loss Discriminator: -0.543, loss Generator: 0.563
# Fretchet Distance:  310.6611788910267
# Epoch [8/30] Batch 0/1563                   Loss Discriminator: -0.735, loss Generator: 0.353
# Epoch [8/30] Batch 100/1563                   Loss Discriminator: -0.675, loss Generator: 0.511
# Epoch [8/30] Batch 200/1563                   Loss Discriminator: -0.519, loss Generator: 0.040
# Epoch [8/30] Batch 300/1563                   Loss Discriminator: -0.704, loss Generator: 0.520
# Epoch [8/30] Batch 400/1563                   Loss Discriminator: -0.687, loss Generator: 0.215
# Epoch [8/30] Batch 500/1563                   Loss Discriminator: -0.649, loss Generator: 0.537
# Epoch [8/30] Batch 600/1563                   Loss Discriminator: -0.510, loss Generator: 0.546
# Epoch [8/30] Batch 700/1563                   Loss Discriminator: -0.691, loss Generator: 0.496
# Epoch [8/30] Batch 800/1563                   Loss Discriminator: -0.698, loss Generator: 0.200
# Epoch [8/30] Batch 900/1563                   Loss Discriminator: -0.522, loss Generator: 0.137
# Epoch [8/30] Batch 1000/1563                   Loss Discriminator: -0.614, loss Generator: 0.561
# Epoch [8/30] Batch 1100/1563                   Loss Discriminator: -0.598, loss Generator: 0.005
# Epoch [8/30] Batch 1200/1563                   Loss Discriminator: -0.712, loss Generator: 0.212
# Epoch [8/30] Batch 1300/1563                   Loss Discriminator: -0.665, loss Generator: 0.572
# Epoch [8/30] Batch 1400/1563                   Loss Discriminator: -0.551, loss Generator: 0.587
# Epoch [8/30] Batch 1500/1563                   Loss Discriminator: -0.678, loss Generator: 0.521
# Fretchet Distance:  286.2991064252402
# Epoch [9/30] Batch 0/1563                   Loss Discriminator: -0.791, loss Generator: 0.455
# Epoch [9/30] Batch 100/1563                   Loss Discriminator: -0.642, loss Generator: 0.478
# Epoch [9/30] Batch 200/1563                   Loss Discriminator: -0.516, loss Generator: 0.542
# Epoch [9/30] Batch 300/1563                   Loss Discriminator: -0.478, loss Generator: 0.528
# Epoch [9/30] Batch 400/1563                   Loss Discriminator: -0.520, loss Generator: 0.127
# Epoch [9/30] Batch 500/1563                   Loss Discriminator: -0.448, loss Generator: -0.023
# Epoch [9/30] Batch 600/1563                   Loss Discriminator: -0.583, loss Generator: 0.113
# Epoch [9/30] Batch 700/1563                   Loss Discriminator: -0.521, loss Generator: 0.153
# Epoch [9/30] Batch 800/1563                   Loss Discriminator: -0.560, loss Generator: 0.149
# Epoch [9/30] Batch 900/1563                   Loss Discriminator: -0.539, loss Generator: 0.152
# Epoch [9/30] Batch 1000/1563                   Loss Discriminator: -0.559, loss Generator: 0.585
# Epoch [9/30] Batch 1100/1563                   Loss Discriminator: -0.650, loss Generator: 0.037
# Epoch [9/30] Batch 1200/1563                   Loss Discriminator: -0.600, loss Generator: 0.582
# Epoch [9/30] Batch 1300/1563                   Loss Discriminator: -0.561, loss Generator: 0.493
# Epoch [9/30] Batch 1400/1563                   Loss Discriminator: -0.558, loss Generator: 0.083
# Epoch [9/30] Batch 1500/1563                   Loss Discriminator: -0.396, loss Generator: 0.506
# Fretchet Distance:  271.7889802073458
# Epoch [10/30] Batch 0/1563                   Loss Discriminator: -0.565, loss Generator: 0.009
# Epoch [10/30] Batch 100/1563                   Loss Discriminator: -0.475, loss Generator: 0.499
# Epoch [10/30] Batch 200/1563                   Loss Discriminator: -0.623, loss Generator: 0.526
# Epoch [10/30] Batch 300/1563                   Loss Discriminator: -0.642, loss Generator: 0.463
# Epoch [10/30] Batch 400/1563                   Loss Discriminator: -0.689, loss Generator: 0.096
# Epoch [10/30] Batch 500/1563                   Loss Discriminator: -0.645, loss Generator: 0.240
# Epoch [10/30] Batch 600/1563                   Loss Discriminator: -0.542, loss Generator: -0.039
# Epoch [10/30] Batch 700/1563                   Loss Discriminator: -0.687, loss Generator: 0.498
# Epoch [10/30] Batch 800/1563                   Loss Discriminator: -0.635, loss Generator: 0.108
# Epoch [10/30] Batch 900/1563                   Loss Discriminator: -0.609, loss Generator: 0.067
# Epoch [10/30] Batch 1000/1563                   Loss Discriminator: -0.564, loss Generator: 0.211
# Epoch [10/30] Batch 1100/1563                   Loss Discriminator: -0.505, loss Generator: -0.123
# Epoch [10/30] Batch 1200/1563                   Loss Discriminator: -0.500, loss Generator: 0.130
# Epoch [10/30] Batch 1300/1563                   Loss Discriminator: -0.581, loss Generator: 0.190
# Epoch [10/30] Batch 1400/1563                   Loss Discriminator: -0.663, loss Generator: 0.466
# Epoch [10/30] Batch 1500/1563                   Loss Discriminator: -0.502, loss Generator: 0.062
# Fretchet Distance:  296.15371070197733
# Epoch [11/30] Batch 0/1563                   Loss Discriminator: -0.631, loss Generator: 0.514
# Epoch [11/30] Batch 100/1563                   Loss Discriminator: -0.509, loss Generator: 0.089
# Epoch [11/30] Batch 200/1563                   Loss Discriminator: -0.585, loss Generator: 0.058
# Epoch [11/30] Batch 300/1563                   Loss Discriminator: -0.504, loss Generator: -0.034
# Epoch [11/30] Batch 400/1563                   Loss Discriminator: -0.546, loss Generator: 0.537
# Epoch [11/30] Batch 500/1563                   Loss Discriminator: -0.494, loss Generator: 0.529
# Epoch [11/30] Batch 600/1563                   Loss Discriminator: -0.691, loss Generator: 0.157
# Epoch [11/30] Batch 700/1563                   Loss Discriminator: -0.540, loss Generator: -0.088
# Epoch [11/30] Batch 800/1563                   Loss Discriminator: -0.429, loss Generator: 0.518
# Epoch [11/30] Batch 900/1563                   Loss Discriminator: -0.502, loss Generator: -0.159
# Epoch [11/30] Batch 1000/1563                   Loss Discriminator: -0.577, loss Generator: 0.485
# Epoch [11/30] Batch 1100/1563                   Loss Discriminator: -0.574, loss Generator: 0.542
# Epoch [11/30] Batch 1200/1563                   Loss Discriminator: -0.487, loss Generator: 0.436
# Epoch [11/30] Batch 1300/1563                   Loss Discriminator: -0.681, loss Generator: -0.044
# Epoch [11/30] Batch 1400/1563                   Loss Discriminator: -0.513, loss Generator: 0.033
# Epoch [11/30] Batch 1500/1563                   Loss Discriminator: -0.445, loss Generator: 0.530
# Fretchet Distance:  296.0871890564417
# Epoch [12/30] Batch 0/1563                   Loss Discriminator: -0.561, loss Generator: 0.546
# Epoch [12/30] Batch 100/1563                   Loss Discriminator: -0.556, loss Generator: 0.054
# Epoch [12/30] Batch 200/1563                   Loss Discriminator: -0.405, loss Generator: 0.515
# Epoch [12/30] Batch 300/1563                   Loss Discriminator: -0.565, loss Generator: 0.105
# Epoch [12/30] Batch 400/1563                   Loss Discriminator: -0.476, loss Generator: 0.453
# Epoch [12/30] Batch 500/1563                   Loss Discriminator: -0.537, loss Generator: 0.078
# Epoch [12/30] Batch 600/1563                   Loss Discriminator: -0.456, loss Generator: -0.030
# Epoch [12/30] Batch 700/1563                   Loss Discriminator: -0.571, loss Generator: 0.148
# Epoch [12/30] Batch 800/1563                   Loss Discriminator: -0.545, loss Generator: 0.003
# Epoch [12/30] Batch 900/1563                   Loss Discriminator: -0.345, loss Generator: 0.483
# Epoch [12/30] Batch 1000/1563                   Loss Discriminator: -0.519, loss Generator: -0.128
# Epoch [12/30] Batch 1100/1563                   Loss Discriminator: -0.537, loss Generator: 0.495
# Epoch [12/30] Batch 1200/1563                   Loss Discriminator: -0.441, loss Generator: 0.060
# Epoch [12/30] Batch 1300/1563                   Loss Discriminator: -0.503, loss Generator: -0.018
# Epoch [12/30] Batch 1400/1563                   Loss Discriminator: -0.533, loss Generator: 0.188
# Epoch [12/30] Batch 1500/1563                   Loss Discriminator: -0.579, loss Generator: -0.034
# Fretchet Distance:  295.9214266669714
# Epoch [13/30] Batch 0/1563                   Loss Discriminator: -0.524, loss Generator: 0.192
# Epoch [13/30] Batch 100/1563                   Loss Discriminator: -0.540, loss Generator: 0.530
# Epoch [13/30] Batch 200/1563                   Loss Discriminator: -0.588, loss Generator: -0.008
# Epoch [13/30] Batch 300/1563                   Loss Discriminator: -0.504, loss Generator: -0.039
# Epoch [13/30] Batch 400/1563                   Loss Discriminator: -0.489, loss Generator: -0.003
# Epoch [13/30] Batch 500/1563                   Loss Discriminator: -0.546, loss Generator: -0.058
# Epoch [13/30] Batch 600/1563                   Loss Discriminator: -0.535, loss Generator: 0.244
# Epoch [13/30] Batch 700/1563                   Loss Discriminator: -0.556, loss Generator: -0.007
# Epoch [13/30] Batch 800/1563                   Loss Discriminator: -0.580, loss Generator: 0.520
# Epoch [13/30] Batch 900/1563                   Loss Discriminator: -0.538, loss Generator: 0.046
# Epoch [13/30] Batch 1000/1563                   Loss Discriminator: -0.555, loss Generator: 0.004
# Epoch [13/30] Batch 1100/1563                   Loss Discriminator: -0.444, loss Generator: 0.495
# Epoch [13/30] Batch 1200/1563                   Loss Discriminator: -0.605, loss Generator: 0.379
# Epoch [13/30] Batch 1300/1563                   Loss Discriminator: -0.410, loss Generator: 0.428
# Epoch [13/30] Batch 1400/1563                   Loss Discriminator: -0.485, loss Generator: 0.032
# Epoch [13/30] Batch 1500/1563                   Loss Discriminator: -0.572, loss Generator: -0.042
# Fretchet Distance:  270.8084816007698
# Epoch [14/30] Batch 0/1563                   Loss Discriminator: -0.495, loss Generator: 0.331
# Epoch [14/30] Batch 100/1563                   Loss Discriminator: -0.585, loss Generator: 0.172
# Epoch [14/30] Batch 200/1563                   Loss Discriminator: -0.505, loss Generator: 0.136
# Epoch [14/30] Batch 300/1563                   Loss Discriminator: -0.501, loss Generator: 0.047
# Epoch [14/30] Batch 400/1563                   Loss Discriminator: -0.529, loss Generator: 0.425
# Epoch [14/30] Batch 500/1563                   Loss Discriminator: -0.605, loss Generator: 0.462
# Epoch [14/30] Batch 600/1563                   Loss Discriminator: -0.557, loss Generator: 0.415
# Epoch [14/30] Batch 700/1563                   Loss Discriminator: -0.596, loss Generator: 0.467
# Epoch [14/30] Batch 800/1563                   Loss Discriminator: -0.530, loss Generator: 0.503
# Epoch [14/30] Batch 900/1563                   Loss Discriminator: -0.571, loss Generator: 0.003
# Epoch [14/30] Batch 1000/1563                   Loss Discriminator: -0.401, loss Generator: -0.046
# Epoch [14/30] Batch 1100/1563                   Loss Discriminator: -0.509, loss Generator: 0.027
# Epoch [14/30] Batch 1200/1563                   Loss Discriminator: -0.580, loss Generator: 0.477
# Epoch [14/30] Batch 1300/1563                   Loss Discriminator: -0.439, loss Generator: 0.444
# Epoch [14/30] Batch 1400/1563                   Loss Discriminator: -0.636, loss Generator: 0.354
# Epoch [14/30] Batch 1500/1563                   Loss Discriminator: -0.439, loss Generator: 0.493
# Fretchet Distance:  280.20306370317905
# Epoch [15/30] Batch 0/1563                   Loss Discriminator: -0.524, loss Generator: 0.059
# Epoch [15/30] Batch 100/1563                   Loss Discriminator: -0.601, loss Generator: 0.318
# Epoch [15/30] Batch 200/1563                   Loss Discriminator: -0.501, loss Generator: -0.136
# Epoch [15/30] Batch 300/1563                   Loss Discriminator: -0.616, loss Generator: 0.535
# Epoch [15/30] Batch 400/1563                   Loss Discriminator: -0.415, loss Generator: -0.062
# Epoch [15/30] Batch 500/1563                   Loss Discriminator: -0.319, loss Generator: 0.449
# Epoch [15/30] Batch 600/1563                   Loss Discriminator: -0.528, loss Generator: 0.038
# Epoch [15/30] Batch 700/1563                   Loss Discriminator: -0.356, loss Generator: 0.054
# Epoch [15/30] Batch 800/1563                   Loss Discriminator: -0.506, loss Generator: 0.077
# Epoch [15/30] Batch 900/1563                   Loss Discriminator: -0.532, loss Generator: 0.532
# Epoch [15/30] Batch 1000/1563                   Loss Discriminator: -0.538, loss Generator: 0.442
# Epoch [15/30] Batch 1100/1563                   Loss Discriminator: -0.543, loss Generator: 0.463
# Epoch [15/30] Batch 1200/1563                   Loss Discriminator: -0.428, loss Generator: 0.435
# Epoch [15/30] Batch 1300/1563                   Loss Discriminator: -0.527, loss Generator: 0.552
# Epoch [15/30] Batch 1400/1563                   Loss Discriminator: -0.384, loss Generator: 0.487
# Epoch [15/30] Batch 1500/1563                   Loss Discriminator: -0.441, loss Generator: 0.521
# Fretchet Distance:  302.2032493125382
# Epoch [16/30] Batch 0/1563                   Loss Discriminator: -0.508, loss Generator: -0.106
# Epoch [16/30] Batch 100/1563                   Loss Discriminator: -0.508, loss Generator: -0.148
# Epoch [16/30] Batch 200/1563                   Loss Discriminator: -0.512, loss Generator: 0.050
# Epoch [16/30] Batch 300/1563                   Loss Discriminator: -0.602, loss Generator: 0.165
# Epoch [16/30] Batch 400/1563                   Loss Discriminator: -0.556, loss Generator: 0.502
# Epoch [16/30] Batch 500/1563                   Loss Discriminator: -0.439, loss Generator: 0.050
# Epoch [16/30] Batch 600/1563                   Loss Discriminator: -0.386, loss Generator: 0.502
# Epoch [16/30] Batch 700/1563                   Loss Discriminator: -0.433, loss Generator: 0.134
# Epoch [16/30] Batch 800/1563                   Loss Discriminator: -0.549, loss Generator: 0.337
# Epoch [16/30] Batch 900/1563                   Loss Discriminator: -0.536, loss Generator: 0.420
# Epoch [16/30] Batch 1000/1563                   Loss Discriminator: -0.592, loss Generator: 0.252
# Epoch [16/30] Batch 1100/1563                   Loss Discriminator: -0.442, loss Generator: 0.504
# Epoch [16/30] Batch 1200/1563                   Loss Discriminator: -0.578, loss Generator: 0.467
# Epoch [16/30] Batch 1300/1563                   Loss Discriminator: -0.447, loss Generator: -0.103
# Epoch [16/30] Batch 1400/1563                   Loss Discriminator: -0.542, loss Generator: 0.218
# Epoch [16/30] Batch 1500/1563                   Loss Discriminator: -0.590, loss Generator: 0.507
# Fretchet Distance:  313.0524390588513
# Epoch [17/30] Batch 0/1563                   Loss Discriminator: -0.553, loss Generator: 0.425
# Epoch [17/30] Batch 100/1563                   Loss Discriminator: -0.435, loss Generator: 0.546
# Epoch [17/30] Batch 200/1563                   Loss Discriminator: -0.448, loss Generator: -0.025
# Epoch [17/30] Batch 300/1563                   Loss Discriminator: -0.428, loss Generator: 0.022
# Epoch [17/30] Batch 400/1563                   Loss Discriminator: -0.471, loss Generator: 0.172
# Epoch [17/30] Batch 500/1563                   Loss Discriminator: -0.504, loss Generator: 0.169
# Epoch [17/30] Batch 600/1563                   Loss Discriminator: -0.564, loss Generator: 0.419
# Epoch [17/30] Batch 700/1563                   Loss Discriminator: -0.640, loss Generator: 0.297
# Epoch [17/30] Batch 800/1563                   Loss Discriminator: -0.411, loss Generator: 0.446
# Epoch [17/30] Batch 900/1563                   Loss Discriminator: -0.471, loss Generator: 0.421
# Epoch [17/30] Batch 1000/1563                   Loss Discriminator: -0.602, loss Generator: 0.299
# Epoch [17/30] Batch 1100/1563                   Loss Discriminator: -0.560, loss Generator: 0.354
# Epoch [17/30] Batch 1200/1563                   Loss Discriminator: -0.499, loss Generator: -0.038
# Epoch [17/30] Batch 1300/1563                   Loss Discriminator: -0.454, loss Generator: 0.511
# Epoch [17/30] Batch 1400/1563                   Loss Discriminator: -0.571, loss Generator: 0.121
# Epoch [17/30] Batch 1500/1563                   Loss Discriminator: -0.516, loss Generator: 0.098
# Fretchet Distance:  285.2318931380179
# Epoch [18/30] Batch 0/1563                   Loss Discriminator: -0.548, loss Generator: 0.445
# Epoch [18/30] Batch 100/1563                   Loss Discriminator: -0.519, loss Generator: 0.161
# Epoch [18/30] Batch 200/1563                   Loss Discriminator: -0.491, loss Generator: 0.090
# Epoch [18/30] Batch 300/1563                   Loss Discriminator: -0.447, loss Generator: 0.488
# Epoch [18/30] Batch 400/1563                   Loss Discriminator: -0.407, loss Generator: 0.027
# Epoch [18/30] Batch 500/1563                   Loss Discriminator: -0.638, loss Generator: 0.417
# Epoch [18/30] Batch 600/1563                   Loss Discriminator: -0.465, loss Generator: 0.436
# Epoch [18/30] Batch 700/1563                   Loss Discriminator: -0.555, loss Generator: 0.323
# Epoch [18/30] Batch 800/1563                   Loss Discriminator: -0.543, loss Generator: 0.348
# Epoch [18/30] Batch 900/1563                   Loss Discriminator: -0.534, loss Generator: -0.034
# Epoch [18/30] Batch 1000/1563                   Loss Discriminator: -0.441, loss Generator: 0.063
# Epoch [18/30] Batch 1100/1563                   Loss Discriminator: -0.417, loss Generator: 0.524
# Epoch [18/30] Batch 1200/1563                   Loss Discriminator: -0.518, loss Generator: -0.005
# Epoch [18/30] Batch 1300/1563                   Loss Discriminator: -0.412, loss Generator: 0.509
# Epoch [18/30] Batch 1400/1563                   Loss Discriminator: -0.440, loss Generator: -0.131
# Epoch [18/30] Batch 1500/1563                   Loss Discriminator: -0.396, loss Generator: 0.029
# Fretchet Distance:  301.6709796017308
# Epoch [19/30] Batch 0/1563                   Loss Discriminator: -0.544, loss Generator: 0.205
# Epoch [19/30] Batch 100/1563                   Loss Discriminator: -0.463, loss Generator: 0.297
# Epoch [19/30] Batch 200/1563                   Loss Discriminator: -0.404, loss Generator: -0.169
# Epoch [19/30] Batch 300/1563                   Loss Discriminator: -0.387, loss Generator: -0.106
# Epoch [19/30] Batch 400/1563                   Loss Discriminator: -0.443, loss Generator: 0.530
# Epoch [19/30] Batch 500/1563                   Loss Discriminator: -0.435, loss Generator: 0.015
# Epoch [19/30] Batch 600/1563                   Loss Discriminator: -0.568, loss Generator: 0.534
# Epoch [19/30] Batch 700/1563                   Loss Discriminator: -0.495, loss Generator: -0.167
# Epoch [19/30] Batch 800/1563                   Loss Discriminator: -0.446, loss Generator: -0.105
# Epoch [19/30] Batch 900/1563                   Loss Discriminator: -0.536, loss Generator: 0.112
# Epoch [19/30] Batch 1000/1563                   Loss Discriminator: -0.469, loss Generator: 0.106
# Epoch [19/30] Batch 1100/1563                   Loss Discriminator: -0.357, loss Generator: 0.543
# Epoch [19/30] Batch 1200/1563                   Loss Discriminator: -0.547, loss Generator: 0.392
# Epoch [19/30] Batch 1300/1563                   Loss Discriminator: -0.456, loss Generator: 0.516
# Epoch [19/30] Batch 1400/1563                   Loss Discriminator: -0.437, loss Generator: -0.133
# Epoch [19/30] Batch 1500/1563                   Loss Discriminator: -0.467, loss Generator: 0.445
# Fretchet Distance:  277.2855872495036
# Epoch [20/30] Batch 0/1563                   Loss Discriminator: -0.455, loss Generator: 0.462
# Epoch [20/30] Batch 100/1563                   Loss Discriminator: -0.541, loss Generator: 0.002
# Epoch [20/30] Batch 200/1563                   Loss Discriminator: -0.484, loss Generator: -0.052
# Epoch [20/30] Batch 300/1563                   Loss Discriminator: -0.315, loss Generator: 0.106
# Epoch [20/30] Batch 400/1563                   Loss Discriminator: -0.366, loss Generator: 0.494
# Epoch [20/30] Batch 500/1563                   Loss Discriminator: -0.545, loss Generator: 0.284
# Epoch [20/30] Batch 600/1563                   Loss Discriminator: -0.354, loss Generator: 0.120
# Epoch [20/30] Batch 700/1563                   Loss Discriminator: -0.430, loss Generator: -0.011
# Epoch [20/30] Batch 800/1563                   Loss Discriminator: -0.474, loss Generator: 0.543
# Epoch [20/30] Batch 900/1563                   Loss Discriminator: -0.590, loss Generator: 0.383
# Epoch [20/30] Batch 1000/1563                   Loss Discriminator: -0.536, loss Generator: 0.004
# Epoch [20/30] Batch 1100/1563                   Loss Discriminator: -0.431, loss Generator: 0.528
# Epoch [20/30] Batch 1200/1563                   Loss Discriminator: -0.394, loss Generator: 0.025
# Epoch [20/30] Batch 1300/1563                   Loss Discriminator: -0.437, loss Generator: 0.126
# Epoch [20/30] Batch 1400/1563                   Loss Discriminator: -0.395, loss Generator: 0.477
# Epoch [20/30] Batch 1500/1563                   Loss Discriminator: -0.426, loss Generator: -0.067
# Fretchet Distance:  270.14855188901845
# Epoch [21/30] Batch 0/1563                   Loss Discriminator: -0.425, loss Generator: 0.139
# Epoch [21/30] Batch 100/1563                   Loss Discriminator: -0.564, loss Generator: 0.165
# Epoch [21/30] Batch 200/1563                   Loss Discriminator: -0.619, loss Generator: 0.461
# Epoch [21/30] Batch 300/1563                   Loss Discriminator: -0.446, loss Generator: 0.005
# Epoch [21/30] Batch 400/1563                   Loss Discriminator: -0.433, loss Generator: -0.158
# Epoch [21/30] Batch 500/1563                   Loss Discriminator: -0.426, loss Generator: -0.111
# Epoch [21/30] Batch 600/1563                   Loss Discriminator: -0.515, loss Generator: 0.333
# Epoch [21/30] Batch 700/1563                   Loss Discriminator: -0.546, loss Generator: 0.535
# Epoch [21/30] Batch 800/1563                   Loss Discriminator: -0.599, loss Generator: 0.426
# Epoch [21/30] Batch 900/1563                   Loss Discriminator: -0.410, loss Generator: -0.101
# Epoch [21/30] Batch 1000/1563                   Loss Discriminator: -0.549, loss Generator: 0.329
# Epoch [21/30] Batch 1100/1563                   Loss Discriminator: -0.486, loss Generator: -0.162
# Epoch [21/30] Batch 1200/1563                   Loss Discriminator: -0.527, loss Generator: 0.118
# Epoch [21/30] Batch 1300/1563                   Loss Discriminator: -0.568, loss Generator: 0.130
# Epoch [21/30] Batch 1400/1563                   Loss Discriminator: -0.517, loss Generator: 0.435
# Epoch [21/30] Batch 1500/1563                   Loss Discriminator: -0.525, loss Generator: 0.297
# Fretchet Distance:  255.70027561621487
# Epoch [22/30] Batch 0/1563                   Loss Discriminator: -0.434, loss Generator: 0.104
# Epoch [22/30] Batch 100/1563                   Loss Discriminator: -0.525, loss Generator: -0.033
# Epoch [22/30] Batch 200/1563                   Loss Discriminator: -0.476, loss Generator: -0.196
# Epoch [22/30] Batch 300/1563                   Loss Discriminator: -0.459, loss Generator: -0.074
# Epoch [22/30] Batch 400/1563                   Loss Discriminator: -0.485, loss Generator: 0.560
# Epoch [22/30] Batch 500/1563                   Loss Discriminator: -0.553, loss Generator: 0.459
# Epoch [22/30] Batch 600/1563                   Loss Discriminator: -0.363, loss Generator: -0.115
# Epoch [22/30] Batch 700/1563                   Loss Discriminator: -0.464, loss Generator: 0.120
# Epoch [22/30] Batch 800/1563                   Loss Discriminator: -0.514, loss Generator: 0.537
# Epoch [22/30] Batch 900/1563                   Loss Discriminator: -0.487, loss Generator: -0.021
# Epoch [22/30] Batch 1000/1563                   Loss Discriminator: -0.354, loss Generator: 0.015
# Epoch [22/30] Batch 1100/1563                   Loss Discriminator: -0.438, loss Generator: 0.441
# Epoch [22/30] Batch 1200/1563                   Loss Discriminator: -0.430, loss Generator: -0.048
# Epoch [22/30] Batch 1300/1563                   Loss Discriminator: -0.446, loss Generator: 0.430
# Epoch [22/30] Batch 1400/1563                   Loss Discriminator: -0.430, loss Generator: 0.116
# Epoch [22/30] Batch 1500/1563                   Loss Discriminator: -0.410, loss Generator: -0.022
# Fretchet Distance:  295.7557560457065
# Epoch [23/30] Batch 0/1563                   Loss Discriminator: -0.379, loss Generator: 0.471
# Epoch [23/30] Batch 100/1563                   Loss Discriminator: -0.496, loss Generator: -0.134
# Epoch [23/30] Batch 200/1563                   Loss Discriminator: -0.422, loss Generator: -0.090
# Epoch [23/30] Batch 300/1563                   Loss Discriminator: -0.483, loss Generator: 0.126
# Epoch [23/30] Batch 400/1563                   Loss Discriminator: -0.467, loss Generator: 0.160
# Epoch [23/30] Batch 500/1563                   Loss Discriminator: -0.418, loss Generator: 0.481
# Epoch [23/30] Batch 600/1563                   Loss Discriminator: -0.437, loss Generator: 0.477
# Epoch [23/30] Batch 700/1563                   Loss Discriminator: -0.512, loss Generator: 0.303
# Epoch [23/30] Batch 800/1563                   Loss Discriminator: -0.456, loss Generator: 0.047
# Epoch [23/30] Batch 900/1563                   Loss Discriminator: -0.498, loss Generator: 0.291
# Epoch [23/30] Batch 1000/1563                   Loss Discriminator: -0.431, loss Generator: 0.061
# Epoch [23/30] Batch 1100/1563                   Loss Discriminator: -0.538, loss Generator: 0.460
# Epoch [23/30] Batch 1200/1563                   Loss Discriminator: -0.494, loss Generator: 0.512
# Epoch [23/30] Batch 1300/1563                   Loss Discriminator: -0.529, loss Generator: 0.207
# Epoch [23/30] Batch 1400/1563                   Loss Discriminator: -0.366, loss Generator: 0.059
# Epoch [23/30] Batch 1500/1563                   Loss Discriminator: -0.451, loss Generator: 0.471
# Fretchet Distance:  271.8171993680503
# Epoch [24/30] Batch 0/1563                   Loss Discriminator: -0.596, loss Generator: 0.306
# Epoch [24/30] Batch 100/1563                   Loss Discriminator: -0.469, loss Generator: -0.208
# Epoch [24/30] Batch 200/1563                   Loss Discriminator: -0.488, loss Generator: 0.464
# Epoch [24/30] Batch 300/1563                   Loss Discriminator: -0.462, loss Generator: 0.372
# Epoch [24/30] Batch 400/1563                   Loss Discriminator: -0.371, loss Generator: 0.361
# Epoch [24/30] Batch 500/1563                   Loss Discriminator: -0.331, loss Generator: 0.064
# Epoch [24/30] Batch 600/1563                   Loss Discriminator: -0.457, loss Generator: 0.351
# Epoch [24/30] Batch 700/1563                   Loss Discriminator: -0.516, loss Generator: 0.261
# Epoch [24/30] Batch 800/1563                   Loss Discriminator: -0.499, loss Generator: 0.445
# Epoch [24/30] Batch 900/1563                   Loss Discriminator: -0.469, loss Generator: -0.241
# Epoch [24/30] Batch 1000/1563                   Loss Discriminator: -0.414, loss Generator: -0.060
# Epoch [24/30] Batch 1100/1563                   Loss Discriminator: -0.541, loss Generator: 0.488
# Epoch [24/30] Batch 1200/1563                   Loss Discriminator: -0.480, loss Generator: 0.027
# Epoch [24/30] Batch 1300/1563                   Loss Discriminator: -0.486, loss Generator: 0.504
# Epoch [24/30] Batch 1400/1563                   Loss Discriminator: -0.519, loss Generator: 0.122
# Epoch [24/30] Batch 1500/1563                   Loss Discriminator: -0.539, loss Generator: 0.229
# Fretchet Distance:  270.187514048672
# Epoch [25/30] Batch 0/1563                   Loss Discriminator: -0.491, loss Generator: 0.359
# Epoch [25/30] Batch 100/1563                   Loss Discriminator: -0.528, loss Generator: 0.570
# Epoch [25/30] Batch 200/1563                   Loss Discriminator: -0.503, loss Generator: 0.055
# Epoch [25/30] Batch 300/1563                   Loss Discriminator: -0.466, loss Generator: 0.478
# Epoch [25/30] Batch 400/1563                   Loss Discriminator: -0.421, loss Generator: -0.153
# Epoch [25/30] Batch 500/1563                   Loss Discriminator: -0.516, loss Generator: 0.458
# Epoch [25/30] Batch 600/1563                   Loss Discriminator: -0.439, loss Generator: 0.052
# Epoch [25/30] Batch 700/1563                   Loss Discriminator: -0.443, loss Generator: -0.154
# Epoch [25/30] Batch 800/1563                   Loss Discriminator: -0.440, loss Generator: 0.464
# Epoch [25/30] Batch 900/1563                   Loss Discriminator: -0.433, loss Generator: -0.045
# Epoch [25/30] Batch 1000/1563                   Loss Discriminator: -0.475, loss Generator: 0.504
# Epoch [25/30] Batch 1100/1563                   Loss Discriminator: -0.398, loss Generator: -0.059
# Epoch [25/30] Batch 1200/1563                   Loss Discriminator: -0.473, loss Generator: -0.180
# Epoch [25/30] Batch 1300/1563                   Loss Discriminator: -0.418, loss Generator: 0.184
# Epoch [25/30] Batch 1400/1563                   Loss Discriminator: -0.483, loss Generator: 0.203
# Epoch [25/30] Batch 1500/1563                   Loss Discriminator: -0.445, loss Generator: 0.458
# Fretchet Distance:  253.04024921013163
# Epoch [26/30] Batch 0/1563                   Loss Discriminator: -0.568, loss Generator: 0.299
# Epoch [26/30] Batch 100/1563                   Loss Discriminator: -0.510, loss Generator: 0.208
# Epoch [26/30] Batch 200/1563                   Loss Discriminator: -0.437, loss Generator: 0.383
# Epoch [26/30] Batch 300/1563                   Loss Discriminator: -0.357, loss Generator: 0.502
# Epoch [26/30] Batch 400/1563                   Loss Discriminator: -0.527, loss Generator: 0.313
# Epoch [26/30] Batch 500/1563                   Loss Discriminator: -0.479, loss Generator: 0.091
# Epoch [26/30] Batch 600/1563                   Loss Discriminator: -0.528, loss Generator: -0.106
# Epoch [26/30] Batch 700/1563                   Loss Discriminator: -0.448, loss Generator: -0.170
# Epoch [26/30] Batch 800/1563                   Loss Discriminator: -0.441, loss Generator: 0.446
# Epoch [26/30] Batch 900/1563                   Loss Discriminator: -0.455, loss Generator: -0.112
# Epoch [26/30] Batch 1000/1563                   Loss Discriminator: -0.486, loss Generator: 0.068
# Epoch [26/30] Batch 1100/1563                   Loss Discriminator: -0.476, loss Generator: -0.022
# Epoch [26/30] Batch 1200/1563                   Loss Discriminator: -0.501, loss Generator: 0.551
# Epoch [26/30] Batch 1300/1563                   Loss Discriminator: -0.515, loss Generator: 0.217
# Epoch [26/30] Batch 1400/1563                   Loss Discriminator: -0.446, loss Generator: 0.136
# Epoch [26/30] Batch 1500/1563                   Loss Discriminator: -0.449, loss Generator: 0.242
# Fretchet Distance:  289.33267613150326
# Epoch [27/30] Batch 0/1563                   Loss Discriminator: -0.398, loss Generator: -0.125
# Epoch [27/30] Batch 100/1563                   Loss Discriminator: -0.312, loss Generator: 0.509
# Epoch [27/30] Batch 200/1563                   Loss Discriminator: -0.515, loss Generator: 0.046
# Epoch [27/30] Batch 300/1563                   Loss Discriminator: -0.480, loss Generator: -0.398
# Epoch [27/30] Batch 400/1563                   Loss Discriminator: -0.408, loss Generator: 0.440
# Epoch [27/30] Batch 500/1563                   Loss Discriminator: -0.361, loss Generator: -0.106
# Epoch [27/30] Batch 600/1563                   Loss Discriminator: -0.330, loss Generator: -0.090
# Epoch [27/30] Batch 700/1563                   Loss Discriminator: -0.501, loss Generator: 0.496
# Epoch [27/30] Batch 800/1563                   Loss Discriminator: -0.406, loss Generator: 0.522
# Epoch [27/30] Batch 900/1563                   Loss Discriminator: -0.409, loss Generator: 0.450
# Epoch [27/30] Batch 1000/1563                   Loss Discriminator: -0.477, loss Generator: 0.568
# Epoch [27/30] Batch 1100/1563                   Loss Discriminator: -0.457, loss Generator: 0.531
# Epoch [27/30] Batch 1200/1563                   Loss Discriminator: -0.364, loss Generator: 0.556
# Epoch [27/30] Batch 1300/1563                   Loss Discriminator: -0.431, loss Generator: 0.538
# Epoch [27/30] Batch 1400/1563                   Loss Discriminator: -0.367, loss Generator: 0.464
# Epoch [27/30] Batch 1500/1563                   Loss Discriminator: -0.514, loss Generator: 0.150
# Fretchet Distance:  254.95965853752392
# Epoch [28/30] Batch 0/1563                   Loss Discriminator: -0.467, loss Generator: 0.352
# Epoch [28/30] Batch 100/1563                   Loss Discriminator: -0.343, loss Generator: 0.368
# Epoch [28/30] Batch 200/1563                   Loss Discriminator: -0.360, loss Generator: -0.016
# Epoch [28/30] Batch 300/1563                   Loss Discriminator: -0.463, loss Generator: 0.203
# Epoch [28/30] Batch 400/1563                   Loss Discriminator: -0.374, loss Generator: 0.331
# Epoch [28/30] Batch 500/1563                   Loss Discriminator: -0.490, loss Generator: 0.432
# Epoch [28/30] Batch 600/1563                   Loss Discriminator: -0.441, loss Generator: 0.402
# Epoch [28/30] Batch 700/1563                   Loss Discriminator: -0.450, loss Generator: 0.071
# Epoch [28/30] Batch 800/1563                   Loss Discriminator: -0.488, loss Generator: 0.393
# Epoch [28/30] Batch 900/1563                   Loss Discriminator: -0.351, loss Generator: 0.461
# Epoch [28/30] Batch 1000/1563                   Loss Discriminator: -0.373, loss Generator: -0.111
# Epoch [28/30] Batch 1100/1563                   Loss Discriminator: -0.456, loss Generator: 0.334
# Epoch [28/30] Batch 1200/1563                   Loss Discriminator: -0.410, loss Generator: 0.491
# Epoch [28/30] Batch 1300/1563                   Loss Discriminator: -0.484, loss Generator: 0.040
# Epoch [28/30] Batch 1400/1563                   Loss Discriminator: -0.452, loss Generator: -0.096
# Epoch [28/30] Batch 1500/1563                   Loss Discriminator: -0.379, loss Generator: -0.215
# Fretchet Distance:  276.59702302250594
# Epoch [29/30] Batch 0/1563                   Loss Discriminator: -0.443, loss Generator: -0.057
# Epoch [29/30] Batch 100/1563                   Loss Discriminator: -0.385, loss Generator: -0.210
# Epoch [29/30] Batch 200/1563                   Loss Discriminator: -0.539, loss Generator: 0.542
# Epoch [29/30] Batch 300/1563                   Loss Discriminator: -0.317, loss Generator: 0.516
# Epoch [29/30] Batch 400/1563                   Loss Discriminator: -0.483, loss Generator: 0.088
# Epoch [29/30] Batch 500/1563                   Loss Discriminator: -0.557, loss Generator: 0.580
# Epoch [29/30] Batch 600/1563                   Loss Discriminator: -0.363, loss Generator: -0.054
# Epoch [29/30] Batch 700/1563                   Loss Discriminator: -0.432, loss Generator: 0.157
# Epoch [29/30] Batch 800/1563                   Loss Discriminator: -0.525, loss Generator: 0.298
# Epoch [29/30] Batch 900/1563                   Loss Discriminator: -0.368, loss Generator: -0.021
# Epoch [29/30] Batch 1000/1563                   Loss Discriminator: -0.393, loss Generator: 0.029
# Epoch [29/30] Batch 1100/1563                   Loss Discriminator: -0.384, loss Generator: -0.217
# Epoch [29/30] Batch 1200/1563                   Loss Discriminator: -0.459, loss Generator: 0.187
# Epoch [29/30] Batch 1300/1563                   Loss Discriminator: -0.469, loss Generator: 0.062
# Epoch [29/30] Batch 1400/1563                   Loss Discriminator: -0.463, loss Generator: 0.035
# Epoch [29/30] Batch 1500/1563                   Loss Discriminator: -0.409, loss Generator: -0.017
# Fretchet Distance:  274.4936072725515

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(GenLoss,label="Gen")
plt.plot(DiscLoss,label="Disc")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.savefig('compare.png')
plt.show()

# %%
import pickle
with open('fd_wgan.pickle', 'wb') as f:
    pickle.dump(fretchet_distances, f)
