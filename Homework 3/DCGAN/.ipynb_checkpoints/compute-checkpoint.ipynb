# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as utils
from IPython.display import HTML
import time
from torchvision import models
import torch.nn.functional as F
from scipy import linalg

# %%
dataset = datasets.CIFAR10(root="/home/nsuresh/Deep-Learning/Homework 3/dataset/CIFAR10data", download=False,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=32,
                                         shuffle=True, num_workers=2)

device = torch.device("cuda")

# %%
real_batch = next(iter(dataloader))
plt.figure(figsize=(10,10))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            # _block(in_channels, out_channels, kernel_size, stride, padding)
            self.Dnet(features_d, features_d * 2, 4, 2, 1),
            self.Dnet(features_d * 2, features_d * 4, 4, 2, 1),
            self.Dnet(features_d * 4, features_d * 8, 4, 2, 1),
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
            nn.Sigmoid(),
        )

    def Dnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            #Gnet(in_channels, out_channels, kernel_size, stride, padding)
            self.Gnet(channels_noise, features_g * 16, 4, 1, 0),
            self.Gnet(features_g * 16, features_g * 8, 4, 2, 1),
            self.Gnet(features_g * 8, features_g * 4, 4, 2, 1),
            self.Gnet(features_g * 4, features_g * 2, 4, 2, 1),
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            nn.Tanh(),
        )

    def Gnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels,momentum=0.9),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
def initialize_weights(model):
    # Initialize weights according to the DCGAN paper
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
#Intitating instances
gen = Generator(channels_noise = 100, channels_img = 3, features_g = 64).to(device)
disc = Discriminator(channels_img = 3, features_d = 64).to(device)
initialize_weights(gen)
initialize_weights(disc)
lr = 2e-4

# %%
optimGenerator = optim.Adam(gen.parameters(), lr=lr, betas=(0.5, 0.999))
optimDiscriminator = optim.Adam(disc.parameters(), lr=lr, betas=(0.5, 0.999))
criterion = nn.BCELoss()
fixed_noise = torch.randn(32, 100, 1, 1).to(device)
step = 0

# %%
class InceptionV3(nn.Module):
    """Pretrained InceptionV3 network returning feature maps"""

    # Index of default block of inception to return,
    # corresponds to output of final average pooling
    DEFAULT_BLOCK_INDEX = 3

    # Maps feature dimensionality to their output blocks indices
    BLOCK_INDEX_BY_DIM = {
        64: 0,
        192: 1,
        768: 2,
        2048: 3
    }

    def __init__(self,
                 output_blocks=[DEFAULT_BLOCK_INDEX],
                 resize_input=True,
                 normalize_input=True,
                 requires_grad=False):
        
        super(InceptionV3, self).__init__()

        self.resize_input = resize_input
        self.normalize_input = normalize_input
        self.output_blocks = sorted(output_blocks)
        self.last_needed_block = max(output_blocks)

        assert self.last_needed_block <= 3, \
            'Last possible output block index is 3'

        self.blocks = nn.ModuleList()

        
        inception = models.inception_v3(pretrained=True)

        # Block 0: input to maxpool1
        block0 = [
            inception.Conv2d_1a_3x3,
            inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2)
        ]
        self.blocks.append(nn.Sequential(*block0))

        # Block 1: maxpool1 to maxpool2
        if self.last_needed_block >= 1:
            block1 = [
                inception.Conv2d_3b_1x1,
                inception.Conv2d_4a_3x3,
                nn.MaxPool2d(kernel_size=3, stride=2)
            ]
            self.blocks.append(nn.Sequential(*block1))

        # Block 2: maxpool2 to aux classifier
        if self.last_needed_block >= 2:
            block2 = [
                inception.Mixed_5b,
                inception.Mixed_5c,
                inception.Mixed_5d,
                inception.Mixed_6a,
                inception.Mixed_6b,
                inception.Mixed_6c,
                inception.Mixed_6d,
                inception.Mixed_6e,
            ]
            self.blocks.append(nn.Sequential(*block2))

        # Block 3: aux classifier to final avgpool
        if self.last_needed_block >= 3:
            block3 = [
                inception.Mixed_7a,
                inception.Mixed_7b,
                inception.Mixed_7c,
                nn.AdaptiveAvgPool2d(output_size=(1, 1))
            ]
            self.blocks.append(nn.Sequential(*block3))

        for param in self.parameters():
            param.requires_grad = requires_grad

    def forward(self, inp):
        outp = []
        x = inp

        if self.resize_input:
            x = F.interpolate(x,
                              size=(299, 299),
                              mode='bilinear',
                              align_corners=False)

        if self.normalize_input:
            x = 2 * x - 1  # Scale from range (0, 1) to range (-1, 1)

        for idx, block in enumerate(self.blocks):
            x = block(x)
            if idx in self.output_blocks:
                outp.append(x)

            if idx == self.last_needed_block:
                break

        return outp
    
block_idx = InceptionV3.BLOCK_INDEX_BY_DIM[2048]
model = InceptionV3([block_idx])
model=model.cuda()

# %%
def calculate_activation_statistics(images, model, batch_size=128, dims=2048, cuda=False):
    model.eval()
    act=np.empty((len(images), dims))
    
    if cuda:
        batch=images.cuda()
    else:
        batch=images
    pred = model(batch)[0]
    if pred.size(2) != 1 or pred.size(3) != 1:
        pred = adaptive_avg_pool2d(pred, output_size=(1, 1))

    act= pred.cpu().data.numpy().reshape(pred.size(0), -1)
    
    mu = np.mean(act, axis=0)
    sigma = np.cov(act, rowvar=False)
    return mu, sigma

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)

    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)

    assert mu1.shape == mu2.shape, \
        'Training and test mean vectors have different lengths'
    assert sigma1.shape == sigma2.shape, \
        'Training and test covariances have different dimensions'

    diff = mu1 - mu2

    
    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        msg = ('fid calculation produces singular product; '
               'adding %s to diagonal of cov estimates') % eps
        print(msg)
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))

    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real

    tr_covmean = np.trace(covmean)

    return (diff.dot(diff) + np.trace(sigma1) +
            np.trace(sigma2) - 2 * tr_covmean)

def calculate_fretchet(images_real,images_fake,model):
    mu_1,std_1 = calculate_activation_statistics(images_real,model,cuda=True)
    mu_2,std_2 = calculate_activation_statistics(images_fake,model,cuda=True)
    fid_value = calculate_frechet_distance(mu_1, std_1, mu_2, std_2)
    return fid_value

# %%
gen.train()
disc.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#     (6): Sigmoid()
#   )
# )

# %%
#training block
GenLoss = []
DiscLoss = []
img_list = []
fretchet_distances = []
iters = 0

print("!!Training Started!!")
# start timing
time_start = time.time()
num_epochs = 30
for epoch in range(num_epochs):
    epoch = epoch+1

    for batch_idx, data in enumerate(dataloader,0):
        #training with real batch
        real = data[0].to(device)
        noise = torch.randn(128, 100, 1, 1).to(device)
        fake = gen(noise) #genrator img data

        ### Train Discriminator: max log(D(x)) + log(1 - D(G(z)))
        disc_real = disc(real).reshape(-1)
        loss_disc_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake.detach()).reshape(-1)
        loss_disc_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        loss_disc = (loss_disc_real + loss_disc_fake) / 2
        disc.zero_grad()
        loss_disc.backward()
        optimDiscriminator.step()

        ### Train Generator: min log(1 - D(G(z))) <-> max log(D(G(z))
        output = disc(fake).reshape(-1)
        loss_gen = criterion(output, torch.ones_like(output))
        gen.zero_grad()
        loss_gen.backward()
        optimGenerator.step()

        # Print losses occasionally and print to tensorboard
        if batch_idx % 100 == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(dataloader)} \
                  Loss Discriminator: {loss_disc:.3f}, loss Generator: {loss_gen:.3f}"
            )
        #saving the losses for every 100 batch
        GenLoss.append(loss_gen.detach().cpu())
        DiscLoss.append(loss_disc.detach().cpu())
        
        
        # Check how the generator is doing by saving G's output on fixed_noise
        if (iters % 500 == 0) or ((epoch == num_epochs) and (batch_idx == len(dataloader)-1)):
            with torch.no_grad():
                fake = gen(fixed_noise).detach().cpu()
            img_list.append(utils.make_grid(fake, padding=2, normalize=True))
            
        iters += 1
    fretchet_dist = calculate_fretchet(real, fake, model)
    print('Fretchet Distance: ', fretchet_dist)
    fretchet_distances.append(fretchet_dist)
        
time_end = time.time()
print('elapsed time：%.2f s.'%(time_end-time_start))
# Out:
# !!Training Started!!
# Epoch [1/30] Batch 0/1563                   Loss Discriminator: 0.691, loss Generator: 0.694
# Epoch [1/30] Batch 100/1563                   Loss Discriminator: 0.224, loss Generator: 3.884
# Epoch [1/30] Batch 200/1563                   Loss Discriminator: 0.302, loss Generator: 2.759
# Epoch [1/30] Batch 300/1563                   Loss Discriminator: 0.378, loss Generator: 1.968
# Epoch [1/30] Batch 400/1563                   Loss Discriminator: 0.347, loss Generator: 1.862
# Epoch [1/30] Batch 500/1563                   Loss Discriminator: 0.396, loss Generator: 0.934
# Epoch [1/30] Batch 600/1563                   Loss Discriminator: 0.590, loss Generator: 0.799
# Epoch [1/30] Batch 700/1563                   Loss Discriminator: 0.525, loss Generator: 0.993
# Epoch [1/30] Batch 800/1563                   Loss Discriminator: 0.577, loss Generator: 0.927
# Epoch [1/30] Batch 900/1563                   Loss Discriminator: 0.716, loss Generator: 1.312
# Epoch [1/30] Batch 1000/1563                   Loss Discriminator: 0.568, loss Generator: 1.188
# Epoch [1/30] Batch 1100/1563                   Loss Discriminator: 0.659, loss Generator: 0.948
# Epoch [1/30] Batch 1200/1563                   Loss Discriminator: 0.651, loss Generator: 1.007
# Epoch [1/30] Batch 1300/1563                   Loss Discriminator: 0.594, loss Generator: 1.635
# Epoch [1/30] Batch 1400/1563                   Loss Discriminator: 0.670, loss Generator: 1.038
# Epoch [1/30] Batch 1500/1563                   Loss Discriminator: 0.634, loss Generator: 0.945
# Fretchet Distance:  397.38844316025313
# Epoch [2/30] Batch 0/1563                   Loss Discriminator: 0.757, loss Generator: 1.122
# Epoch [2/30] Batch 100/1563                   Loss Discriminator: 0.718, loss Generator: 0.903
# Epoch [2/30] Batch 200/1563                   Loss Discriminator: 0.653, loss Generator: 1.018
# Epoch [2/30] Batch 300/1563                   Loss Discriminator: 0.572, loss Generator: 1.250
# Epoch [2/30] Batch 400/1563                   Loss Discriminator: 0.592, loss Generator: 0.966
# Epoch [2/30] Batch 500/1563                   Loss Discriminator: 0.679, loss Generator: 1.298
# Epoch [2/30] Batch 600/1563                   Loss Discriminator: 0.651, loss Generator: 1.168
# Epoch [2/30] Batch 700/1563                   Loss Discriminator: 0.593, loss Generator: 1.113
# Epoch [2/30] Batch 800/1563                   Loss Discriminator: 0.487, loss Generator: 1.385
# Epoch [2/30] Batch 900/1563                   Loss Discriminator: 0.695, loss Generator: 0.921
# Epoch [2/30] Batch 1000/1563                   Loss Discriminator: 0.623, loss Generator: 0.931
# Epoch [2/30] Batch 1100/1563                   Loss Discriminator: 0.607, loss Generator: 1.025
# Epoch [2/30] Batch 1200/1563                   Loss Discriminator: 0.608, loss Generator: 1.009
# Epoch [2/30] Batch 1300/1563                   Loss Discriminator: 0.624, loss Generator: 1.211
# Epoch [2/30] Batch 1400/1563                   Loss Discriminator: 0.626, loss Generator: 0.955
# Epoch [2/30] Batch 1500/1563                   Loss Discriminator: 0.695, loss Generator: 1.756
# Fretchet Distance:  302.00756399544036
# Epoch [3/30] Batch 0/1563                   Loss Discriminator: 0.670, loss Generator: 1.156
# Epoch [3/30] Batch 100/1563                   Loss Discriminator: 0.668, loss Generator: 0.956
# Epoch [3/30] Batch 200/1563                   Loss Discriminator: 1.079, loss Generator: 1.460
# Epoch [3/30] Batch 300/1563                   Loss Discriminator: 0.666, loss Generator: 1.044
# Epoch [3/30] Batch 400/1563                   Loss Discriminator: 0.573, loss Generator: 1.092
# Epoch [3/30] Batch 500/1563                   Loss Discriminator: 0.541, loss Generator: 1.202
# Epoch [3/30] Batch 600/1563                   Loss Discriminator: 0.718, loss Generator: 0.964
# Epoch [3/30] Batch 700/1563                   Loss Discriminator: 0.655, loss Generator: 0.823
# Epoch [3/30] Batch 800/1563                   Loss Discriminator: 0.625, loss Generator: 0.857
# Epoch [3/30] Batch 900/1563                   Loss Discriminator: 0.871, loss Generator: 1.301
# Epoch [3/30] Batch 1000/1563                   Loss Discriminator: 0.718, loss Generator: 0.723
# Epoch [3/30] Batch 1100/1563                   Loss Discriminator: 0.738, loss Generator: 0.679
# Epoch [3/30] Batch 1200/1563                   Loss Discriminator: 0.672, loss Generator: 0.786
# Epoch [3/30] Batch 1300/1563                   Loss Discriminator: 0.746, loss Generator: 1.099
# Epoch [3/30] Batch 1400/1563                   Loss Discriminator: 0.698, loss Generator: 1.116
# Epoch [3/30] Batch 1500/1563                   Loss Discriminator: 0.691, loss Generator: 0.918
# Fretchet Distance:  281.18848184487535
# Epoch [4/30] Batch 0/1563                   Loss Discriminator: 0.659, loss Generator: 0.756
# Epoch [4/30] Batch 100/1563                   Loss Discriminator: 0.628, loss Generator: 0.999
# Epoch [4/30] Batch 200/1563                   Loss Discriminator: 0.729, loss Generator: 1.108
# Epoch [4/30] Batch 300/1563                   Loss Discriminator: 0.730, loss Generator: 1.056
# Epoch [4/30] Batch 400/1563                   Loss Discriminator: 0.657, loss Generator: 0.870
# Epoch [4/30] Batch 500/1563                   Loss Discriminator: 0.737, loss Generator: 0.830
# Epoch [4/30] Batch 600/1563                   Loss Discriminator: 0.598, loss Generator: 0.792
# Epoch [4/30] Batch 700/1563                   Loss Discriminator: 0.642, loss Generator: 0.965
# Epoch [4/30] Batch 800/1563                   Loss Discriminator: 0.598, loss Generator: 0.826
# Epoch [4/30] Batch 900/1563                   Loss Discriminator: 0.707, loss Generator: 0.623
# Epoch [4/30] Batch 1000/1563                   Loss Discriminator: 0.705, loss Generator: 0.853
# Epoch [4/30] Batch 1100/1563                   Loss Discriminator: 0.651, loss Generator: 0.761
# Epoch [4/30] Batch 1200/1563                   Loss Discriminator: 0.489, loss Generator: 1.252
# Epoch [4/30] Batch 1300/1563                   Loss Discriminator: 0.729, loss Generator: 0.835
# Epoch [4/30] Batch 1400/1563                   Loss Discriminator: 0.633, loss Generator: 0.844
# Epoch [4/30] Batch 1500/1563                   Loss Discriminator: 0.703, loss Generator: 0.772
# Fretchet Distance:  259.0501052820967
# Epoch [5/30] Batch 0/1563                   Loss Discriminator: 0.682, loss Generator: 0.873
# Epoch [5/30] Batch 100/1563                   Loss Discriminator: 0.592, loss Generator: 0.750
# Epoch [5/30] Batch 200/1563                   Loss Discriminator: 0.652, loss Generator: 1.001
# Epoch [5/30] Batch 300/1563                   Loss Discriminator: 0.599, loss Generator: 0.941
# Epoch [5/30] Batch 400/1563                   Loss Discriminator: 0.773, loss Generator: 1.044
# Epoch [5/30] Batch 500/1563                   Loss Discriminator: 0.623, loss Generator: 0.694
# Epoch [5/30] Batch 600/1563                   Loss Discriminator: 0.645, loss Generator: 0.959
# Epoch [5/30] Batch 700/1563                   Loss Discriminator: 0.724, loss Generator: 0.755
# Epoch [5/30] Batch 800/1563                   Loss Discriminator: 0.704, loss Generator: 0.918
# Epoch [5/30] Batch 900/1563                   Loss Discriminator: 0.647, loss Generator: 0.936
# Epoch [5/30] Batch 1000/1563                   Loss Discriminator: 0.640, loss Generator: 1.033
# Epoch [5/30] Batch 1100/1563                   Loss Discriminator: 0.659, loss Generator: 0.797
# Epoch [5/30] Batch 1200/1563                   Loss Discriminator: 0.696, loss Generator: 0.852
# Epoch [5/30] Batch 1300/1563                   Loss Discriminator: 0.612, loss Generator: 0.802
# Epoch [5/30] Batch 1400/1563                   Loss Discriminator: 0.690, loss Generator: 0.746
# Epoch [5/30] Batch 1500/1563                   Loss Discriminator: 0.667, loss Generator: 0.891
# Fretchet Distance:  256.1006087035922
# Epoch [6/30] Batch 0/1563                   Loss Discriminator: 0.645, loss Generator: 0.846
# Epoch [6/30] Batch 100/1563                   Loss Discriminator: 0.730, loss Generator: 0.813
# Epoch [6/30] Batch 200/1563                   Loss Discriminator: 0.673, loss Generator: 0.901
# Epoch [6/30] Batch 300/1563                   Loss Discriminator: 0.666, loss Generator: 1.057
# Epoch [6/30] Batch 400/1563                   Loss Discriminator: 0.699, loss Generator: 1.034
# Epoch [8/30] Batch 700/1563                   Loss Discriminator: 0.847, loss Generator: 0.847
# Epoch [8/30] Batch 800/1563                   Loss Discriminator: 0.590, loss Generator: 0.908
# Epoch [8/30] Batch 900/1563                   Loss Discriminator: 0.550, loss Generator: 0.815
# Epoch [8/30] Batch 1000/1563                   Loss Discriminator: 0.687, loss Generator: 1.161
# Epoch [8/30] Batch 1100/1563                   Loss Discriminator: 0.594, loss Generator: 0.931
# Epoch [8/30] Batch 1200/1563                   Loss Discriminator: 0.549, loss Generator: 0.981
# Epoch [8/30] Batch 1300/1563                   Loss Discriminator: 0.560, loss Generator: 1.365
# Epoch [8/30] Batch 1400/1563                   Loss Discriminator: 0.649, loss Generator: 0.783
# Epoch [8/30] Batch 1500/1563                   Loss Discriminator: 0.617, loss Generator: 0.914
# Fretchet Distance:  270.37780692835463
# Epoch [9/30] Batch 0/1563                   Loss Discriminator: 0.594, loss Generator: 0.803
# Epoch [9/30] Batch 100/1563                   Loss Discriminator: 0.679, loss Generator: 0.750
# Epoch [9/30] Batch 200/1563                   Loss Discriminator: 0.595, loss Generator: 1.310
# Epoch [9/30] Batch 300/1563                   Loss Discriminator: 0.651, loss Generator: 1.009
# Epoch [9/30] Batch 400/1563                   Loss Discriminator: 0.624, loss Generator: 1.177
# Epoch [9/30] Batch 500/1563                   Loss Discriminator: 0.666, loss Generator: 0.924
# Epoch [9/30] Batch 600/1563                   Loss Discriminator: 0.658, loss Generator: 0.822
# Epoch [9/30] Batch 700/1563                   Loss Discriminator: 0.593, loss Generator: 1.185
# Epoch [9/30] Batch 800/1563                   Loss Discriminator: 0.650, loss Generator: 0.786
# Epoch [9/30] Batch 900/1563                   Loss Discriminator: 0.645, loss Generator: 0.962
# Epoch [9/30] Batch 1000/1563                   Loss Discriminator: 0.618, loss Generator: 1.013
# Epoch [9/30] Batch 1100/1563                   Loss Discriminator: 0.654, loss Generator: 0.876
# Epoch [9/30] Batch 1200/1563                   Loss Discriminator: 0.678, loss Generator: 0.832
# Epoch [9/30] Batch 1300/1563                   Loss Discriminator: 0.686, loss Generator: 0.764
# Epoch [9/30] Batch 1400/1563                   Loss Discriminator: 0.685, loss Generator: 0.747
# Epoch [9/30] Batch 1500/1563                   Loss Discriminator: 0.660, loss Generator: 0.913
# Fretchet Distance:  254.36738152936857
# Epoch [10/30] Batch 0/1563                   Loss Discriminator: 0.691, loss Generator: 0.991
# Epoch [10/30] Batch 100/1563                   Loss Discriminator: 0.561, loss Generator: 0.828
# Epoch [10/30] Batch 200/1563                   Loss Discriminator: 0.645, loss Generator: 0.876
# Epoch [10/30] Batch 300/1563                   Loss Discriminator: 0.650, loss Generator: 0.930
# Epoch [10/30] Batch 400/1563                   Loss Discriminator: 0.515, loss Generator: 1.051
# Epoch [10/30] Batch 500/1563                   Loss Discriminator: 0.580, loss Generator: 0.806
# Epoch [10/30] Batch 600/1563                   Loss Discriminator: 0.658, loss Generator: 0.957
# Epoch [10/30] Batch 700/1563                   Loss Discriminator: 0.640, loss Generator: 0.930
# Epoch [10/30] Batch 800/1563                   Loss Discriminator: 0.614, loss Generator: 0.840
# Epoch [10/30] Batch 900/1563                   Loss Discriminator: 0.649, loss Generator: 0.781
# Epoch [10/30] Batch 1000/1563                   Loss Discriminator: 0.639, loss Generator: 1.015
# Epoch [10/30] Batch 1100/1563                   Loss Discriminator: 0.475, loss Generator: 1.096
# Epoch [10/30] Batch 1200/1563                   Loss Discriminator: 0.667, loss Generator: 0.819
# Epoch [10/30] Batch 1300/1563                   Loss Discriminator: 0.601, loss Generator: 0.995
# Epoch [10/30] Batch 1400/1563                   Loss Discriminator: 0.756, loss Generator: 1.332
# Epoch [10/30] Batch 1500/1563                   Loss Discriminator: 0.665, loss Generator: 0.932
# Fretchet Distance:  251.1166600223154
# Epoch [11/30] Batch 0/1563                   Loss Discriminator: 0.764, loss Generator: 1.359
# Epoch [11/30] Batch 100/1563                   Loss Discriminator: 0.620, loss Generator: 0.606
# Epoch [11/30] Batch 200/1563                   Loss Discriminator: 0.589, loss Generator: 0.829
# Epoch [11/30] Batch 300/1563                   Loss Discriminator: 0.658, loss Generator: 1.181
# Epoch [11/30] Batch 400/1563                   Loss Discriminator: 0.684, loss Generator: 0.719
# Epoch [11/30] Batch 500/1563                   Loss Discriminator: 0.689, loss Generator: 0.737
# Epoch [11/30] Batch 600/1563                   Loss Discriminator: 0.687, loss Generator: 0.784
# Epoch [11/30] Batch 700/1563                   Loss Discriminator: 0.627, loss Generator: 1.032
# Epoch [11/30] Batch 800/1563                   Loss Discriminator: 0.535, loss Generator: 0.599
# Epoch [11/30] Batch 900/1563                   Loss Discriminator: 0.624, loss Generator: 1.057
# Epoch [11/30] Batch 1000/1563                   Loss Discriminator: 0.592, loss Generator: 0.861
# Epoch [11/30] Batch 1100/1563                   Loss Discriminator: 0.655, loss Generator: 0.917
# Epoch [11/30] Batch 1200/1563                   Loss Discriminator: 0.544, loss Generator: 1.032
# Epoch [11/30] Batch 1300/1563                   Loss Discriminator: 0.641, loss Generator: 1.147
# Epoch [11/30] Batch 1400/1563                   Loss Discriminator: 0.496, loss Generator: 0.870
# Epoch [11/30] Batch 1500/1563                   Loss Discriminator: 0.577, loss Generator: 0.977
# Fretchet Distance:  252.95237986330932
# Epoch [12/30] Batch 0/1563                   Loss Discriminator: 0.619, loss Generator: 0.982
# Epoch [12/30] Batch 100/1563                   Loss Discriminator: 0.664, loss Generator: 1.218
# Epoch [12/30] Batch 200/1563                   Loss Discriminator: 0.718, loss Generator: 0.906
# Epoch [12/30] Batch 300/1563                   Loss Discriminator: 0.710, loss Generator: 1.203
# Epoch [12/30] Batch 400/1563                   Loss Discriminator: 0.515, loss Generator: 1.445
# Epoch [12/30] Batch 500/1563                   Loss Discriminator: 0.549, loss Generator: 1.154
# Epoch [12/30] Batch 600/1563                   Loss Discriminator: 0.607, loss Generator: 0.974
# Epoch [12/30] Batch 700/1563                   Loss Discriminator: 0.467, loss Generator: 1.159
# Epoch [12/30] Batch 800/1563                   Loss Discriminator: 0.532, loss Generator: 1.118
# Epoch [12/30] Batch 900/1563                   Loss Discriminator: 0.682, loss Generator: 0.823
# Epoch [23/30] Batch 0/1563                   Loss Discriminator: 0.549, loss Generator: 1.159
# Epoch [23/30] Batch 100/1563                   Loss Discriminator: 0.525, loss Generator: 1.073
# Epoch [23/30] Batch 200/1563                   Loss Discriminator: 0.806, loss Generator: 1.433
# Epoch [23/30] Batch 300/1563                   Loss Discriminator: 0.889, loss Generator: 1.607
# Epoch [23/30] Batch 400/1563                   Loss Discriminator: 0.518, loss Generator: 1.528
# Epoch [23/30] Batch 500/1563                   Loss Discriminator: 0.560, loss Generator: 1.043
# Epoch [23/30] Batch 600/1563                   Loss Discriminator: 0.473, loss Generator: 1.671
# Epoch [23/30] Batch 700/1563                   Loss Discriminator: 0.457, loss Generator: 1.282
# Epoch [23/30] Batch 800/1563                   Loss Discriminator: 0.483, loss Generator: 1.532
# Epoch [23/30] Batch 900/1563                   Loss Discriminator: 0.580, loss Generator: 1.406
# Epoch [23/30] Batch 1000/1563                   Loss Discriminator: 0.553, loss Generator: 1.183
# Epoch [23/30] Batch 1100/1563                   Loss Discriminator: 0.613, loss Generator: 1.073
# Epoch [23/30] Batch 1200/1563                   Loss Discriminator: 0.664, loss Generator: 1.152
# Epoch [23/30] Batch 1300/1563                   Loss Discriminator: 0.530, loss Generator: 1.725
# Epoch [23/30] Batch 1400/1563                   Loss Discriminator: 0.514, loss Generator: 1.125
# Epoch [23/30] Batch 1500/1563                   Loss Discriminator: 0.487, loss Generator: 1.238
# Fretchet Distance:  254.16995502269623
# Epoch [24/30] Batch 0/1563                   Loss Discriminator: 0.724, loss Generator: 1.077
# Epoch [24/30] Batch 100/1563                   Loss Discriminator: 0.545, loss Generator: 1.128
# Epoch [24/30] Batch 200/1563                   Loss Discriminator: 0.446, loss Generator: 1.226
# Epoch [24/30] Batch 300/1563                   Loss Discriminator: 0.518, loss Generator: 1.339
# Epoch [24/30] Batch 400/1563                   Loss Discriminator: 0.533, loss Generator: 1.366
# Epoch [24/30] Batch 500/1563                   Loss Discriminator: 0.359, loss Generator: 1.628
# Epoch [24/30] Batch 600/1563                   Loss Discriminator: 0.557, loss Generator: 1.154
# Epoch [24/30] Batch 700/1563                   Loss Discriminator: 0.530, loss Generator: 1.213
# Epoch [24/30] Batch 800/1563                   Loss Discriminator: 0.427, loss Generator: 1.521
# Epoch [24/30] Batch 900/1563                   Loss Discriminator: 0.420, loss Generator: 1.276
# Epoch [24/30] Batch 1000/1563                   Loss Discriminator: 0.459, loss Generator: 1.351
# Epoch [24/30] Batch 1100/1563                   Loss Discriminator: 0.399, loss Generator: 1.396
# Epoch [24/30] Batch 1200/1563                   Loss Discriminator: 0.692, loss Generator: 1.342
# Epoch [24/30] Batch 1300/1563                   Loss Discriminator: 0.430, loss Generator: 1.559
# Epoch [24/30] Batch 1400/1563                   Loss Discriminator: 0.524, loss Generator: 1.515
# Epoch [24/30] Batch 1500/1563                   Loss Discriminator: 0.532, loss Generator: 1.236
# Fretchet Distance:  250.23770655140783
# Epoch [25/30] Batch 0/1563                   Loss Discriminator: 0.466, loss Generator: 1.489
# Epoch [25/30] Batch 100/1563                   Loss Discriminator: 0.546, loss Generator: 1.263
# Epoch [25/30] Batch 200/1563                   Loss Discriminator: 0.487, loss Generator: 1.490
# Epoch [25/30] Batch 300/1563                   Loss Discriminator: 0.457, loss Generator: 1.617
# Epoch [25/30] Batch 400/1563                   Loss Discriminator: 0.451, loss Generator: 1.791
# Epoch [25/30] Batch 500/1563                   Loss Discriminator: 0.479, loss Generator: 1.375
# Epoch [25/30] Batch 600/1563                   Loss Discriminator: 0.531, loss Generator: 1.183
# Epoch [25/30] Batch 700/1563                   Loss Discriminator: 0.567, loss Generator: 1.245
# Epoch [25/30] Batch 800/1563                   Loss Discriminator: 0.664, loss Generator: 1.448
# Epoch [25/30] Batch 900/1563                   Loss Discriminator: 0.501, loss Generator: 1.269
# Epoch [25/30] Batch 1000/1563                   Loss Discriminator: 0.607, loss Generator: 1.218
# Epoch [25/30] Batch 1100/1563                   Loss Discriminator: 0.561, loss Generator: 1.181
# Epoch [25/30] Batch 1200/1563                   Loss Discriminator: 0.542, loss Generator: 0.986
# Epoch [25/30] Batch 1300/1563                   Loss Discriminator: 0.427, loss Generator: 1.716
# Epoch [25/30] Batch 1400/1563                   Loss Discriminator: 0.536, loss Generator: 1.479
# Epoch [25/30] Batch 1500/1563                   Loss Discriminator: 0.519, loss Generator: 1.485
# Fretchet Distance:  250.798661378092
# Epoch [26/30] Batch 0/1563                   Loss Discriminator: 0.533, loss Generator: 1.369
# Epoch [26/30] Batch 100/1563                   Loss Discriminator: 0.681, loss Generator: 1.454
# Epoch [26/30] Batch 200/1563                   Loss Discriminator: 0.478, loss Generator: 1.324
# Epoch [26/30] Batch 300/1563                   Loss Discriminator: 0.372, loss Generator: 1.595
# Epoch [26/30] Batch 400/1563                   Loss Discriminator: 0.418, loss Generator: 1.395
# Epoch [26/30] Batch 500/1563                   Loss Discriminator: 0.559, loss Generator: 1.197
# Epoch [26/30] Batch 600/1563                   Loss Discriminator: 0.326, loss Generator: 1.833
# Epoch [26/30] Batch 700/1563                   Loss Discriminator: 0.545, loss Generator: 1.244
# Epoch [26/30] Batch 800/1563                   Loss Discriminator: 0.530, loss Generator: 1.222
# Epoch [26/30] Batch 900/1563                   Loss Discriminator: 0.519, loss Generator: 1.481
# Epoch [26/30] Batch 1000/1563                   Loss Discriminator: 0.545, loss Generator: 1.342
# Epoch [26/30] Batch 1100/1563                   Loss Discriminator: 0.471, loss Generator: 1.568
# Epoch [26/30] Batch 1200/1563                   Loss Discriminator: 0.353, loss Generator: 1.532
# Epoch [26/30] Batch 1300/1563                   Loss Discriminator: 0.722, loss Generator: 1.512
# Epoch [26/30] Batch 1400/1563                   Loss Discriminator: 0.425, loss Generator: 1.641
# Epoch [26/30] Batch 1500/1563                   Loss Discriminator: 0.439, loss Generator: 1.584
# Fretchet Distance:  257.50882320433476
# Epoch [27/30] Batch 0/1563                   Loss Discriminator: 0.395, loss Generator: 1.599
# Epoch [27/30] Batch 100/1563                   Loss Discriminator: 0.510, loss Generator: 1.423
# Epoch [27/30] Batch 200/1563                   Loss Discriminator: 0.404, loss Generator: 1.359
# Epoch [27/30] Batch 300/1563                   Loss Discriminator: 0.431, loss Generator: 1.657
# Epoch [27/30] Batch 400/1563                   Loss Discriminator: 0.403, loss Generator: 1.575
# Epoch [27/30] Batch 500/1563                   Loss Discriminator: 0.377, loss Generator: 1.696
# Epoch [27/30] Batch 600/1563                   Loss Discriminator: 0.336, loss Generator: 1.719
# Epoch [27/30] Batch 700/1563                   Loss Discriminator: 0.442, loss Generator: 1.242
# Epoch [27/30] Batch 800/1563                   Loss Discriminator: 0.501, loss Generator: 1.529
# Epoch [27/30] Batch 900/1563                   Loss Discriminator: 0.530, loss Generator: 1.946
# Epoch [27/30] Batch 1000/1563                   Loss Discriminator: 0.407, loss Generator: 1.756
# Epoch [27/30] Batch 1100/1563                   Loss Discriminator: 0.427, loss Generator: 1.349
# Epoch [27/30] Batch 1200/1563                   Loss Discriminator: 0.449, loss Generator: 1.349
# Epoch [27/30] Batch 1300/1563                   Loss Discriminator: 0.401, loss Generator: 1.688
# Epoch [27/30] Batch 1400/1563                   Loss Discriminator: 0.617, loss Generator: 0.971
# Epoch [27/30] Batch 1500/1563                   Loss Discriminator: 0.855, loss Generator: 1.669
# Fretchet Distance:  262.54583569200446
# Epoch [28/30] Batch 0/1563                   Loss Discriminator: 0.519, loss Generator: 1.321
# Epoch [28/30] Batch 100/1563                   Loss Discriminator: 0.306, loss Generator: 1.832
# Epoch [28/30] Batch 200/1563                   Loss Discriminator: 0.459, loss Generator: 1.680
# Epoch [28/30] Batch 300/1563                   Loss Discriminator: 0.448, loss Generator: 1.731
# Epoch [28/30] Batch 400/1563                   Loss Discriminator: 0.394, loss Generator: 1.659
# Epoch [28/30] Batch 500/1563                   Loss Discriminator: 0.524, loss Generator: 1.122
# Epoch [28/30] Batch 600/1563                   Loss Discriminator: 0.453, loss Generator: 1.577
# Epoch [28/30] Batch 700/1563                   Loss Discriminator: 0.421, loss Generator: 1.728
# Epoch [28/30] Batch 800/1563                   Loss Discriminator: 0.392, loss Generator: 1.820
# Epoch [28/30] Batch 900/1563                   Loss Discriminator: 0.522, loss Generator: 1.381
# Epoch [28/30] Batch 1000/1563                   Loss Discriminator: 0.448, loss Generator: 1.426
# Epoch [28/30] Batch 1100/1563                   Loss Discriminator: 0.420, loss Generator: 1.454
# Epoch [28/30] Batch 1200/1563                   Loss Discriminator: 0.469, loss Generator: 1.511
# Epoch [28/30] Batch 1300/1563                   Loss Discriminator: 0.420, loss Generator: 1.540
# Epoch [28/30] Batch 1400/1563                   Loss Discriminator: 0.308, loss Generator: 1.582
# Epoch [28/30] Batch 1500/1563                   Loss Discriminator: 0.404, loss Generator: 1.477
# Fretchet Distance:  267.4426481654908
# Epoch [29/30] Batch 0/1563                   Loss Discriminator: 0.432, loss Generator: 1.933
# Epoch [29/30] Batch 100/1563                   Loss Discriminator: 0.426, loss Generator: 1.464
# Epoch [29/30] Batch 200/1563                   Loss Discriminator: 0.370, loss Generator: 1.934
# Epoch [29/30] Batch 300/1563                   Loss Discriminator: 0.392, loss Generator: 1.888
# Epoch [29/30] Batch 400/1563                   Loss Discriminator: 0.425, loss Generator: 1.707
# Epoch [29/30] Batch 500/1563                   Loss Discriminator: 0.515, loss Generator: 1.549
# Epoch [29/30] Batch 600/1563                   Loss Discriminator: 0.495, loss Generator: 2.112
# Epoch [29/30] Batch 700/1563                   Loss Discriminator: 0.396, loss Generator: 1.465
# Epoch [29/30] Batch 800/1563                   Loss Discriminator: 0.395, loss Generator: 1.658
# Epoch [29/30] Batch 900/1563                   Loss Discriminator: 0.372, loss Generator: 1.423
# Epoch [29/30] Batch 1000/1563                   Loss Discriminator: 0.432, loss Generator: 1.648
# Epoch [29/30] Batch 1100/1563                   Loss Discriminator: 0.556, loss Generator: 1.314
# Epoch [29/30] Batch 1200/1563                   Loss Discriminator: 0.373, loss Generator: 1.824
# Epoch [29/30] Batch 1300/1563                   Loss Discriminator: 0.411, loss Generator: 1.447
# Epoch [29/30] Batch 1400/1563                   Loss Discriminator: 0.433, loss Generator: 1.563
# Epoch [29/30] Batch 1500/1563                   Loss Discriminator: 0.465, loss Generator: 1.417
# Fretchet Distance:  264.23633481392835
# Epoch [30/30] Batch 0/1563                   Loss Discriminator: 0.444, loss Generator: 1.383
# Epoch [30/30] Batch 100/1563                   Loss Discriminator: 0.439, loss Generator: 2.224
# Epoch [30/30] Batch 200/1563                   Loss Discriminator: 0.357, loss Generator: 1.527
# Epoch [30/30] Batch 300/1563                   Loss Discriminator: 0.360, loss Generator: 1.328
# Epoch [30/30] Batch 400/1563                   Loss Discriminator: 0.353, loss Generator: 1.691
# Epoch [30/30] Batch 500/1563                   Loss Discriminator: 0.380, loss Generator: 1.628
# Epoch [30/30] Batch 600/1563                   Loss Discriminator: 0.373, loss Generator: 1.556
# Epoch [30/30] Batch 700/1563                   Loss Discriminator: 0.343, loss Generator: 2.021
# Epoch [30/30] Batch 800/1563                   Loss Discriminator: 0.391, loss Generator: 1.463
# Epoch [30/30] Batch 900/1563                   Loss Discriminator: 0.472, loss Generator: 1.681
# Epoch [30/30] Batch 1000/1563                   Loss Discriminator: 0.455, loss Generator: 1.343
# Epoch [30/30] Batch 1100/1563                   Loss Discriminator: 0.552, loss Generator: 1.497
# Epoch [30/30] Batch 1200/1563                   Loss Discriminator: 0.368, loss Generator: 1.681
# Epoch [30/30] Batch 1300/1563                   Loss Discriminator: 0.352, loss Generator: 1.963
# Epoch [30/30] Batch 1400/1563                   Loss Discriminator: 0.436, loss Generator: 1.545
# Epoch [30/30] Batch 1500/1563                   Loss Discriminator: 0.350, loss Generator: 1.871
# Fretchet Distance:  277.90966165951465
# elapsed time：4177.62 s.

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(GenLoss,label="Gen")
plt.plot(DiscLoss,label="Disc")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.savefig('compare.png')
plt.show()

# %%
import pickle
with open('fd_dcgan.pickle', 'wb') as f:
    pickle.dump(fretchet_distances, f)

# %%
file = open('fd_wgan.pickle', 'rb')
wgan = pickle.load(file)
dcgan = fretchet_distances

# %%
plt.plot(np.arange(1,31), dcgan, label = 'DCGAN')
plt.plot(np.arange(1,31), wgan, label = 'WGAN')
plt.title('Fretchet Distance for 30 epochs')
plt.legend()
plt.show()
