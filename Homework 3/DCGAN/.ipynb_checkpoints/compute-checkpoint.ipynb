# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as utils
import matplotlib.animation as animation
from IPython.display import HTML
import time

# %%
dataset = datasets.CIFAR10(root="/home/nsuresh/Deep-Learning/Homework 3/dataset/CIFAR10data", download=False,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=32,
                                         shuffle=True, num_workers=2)

device = torch.device("cuda")

# %%
real_batch = next(iter(dataloader))
plt.figure(figsize=(10,10))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
class Generator(nn.Module):
    def __init__(self, channels_noise = 100, channels_img = 3, features_g = 64):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            # Input: N x channels_noise x 1 x 1
            self.Gnet(channels_noise, features_g * 16, 4, 1, 0),
            self.Gnet(features_g * 16, features_g * 8, 4, 2, 1),
            self.Gnet(features_g * 8, features_g * 4, 4, 2, 1),
            self.Gnet(features_g * 4, features_g * 2, 4, 2, 1),
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            # Output: N x channels_img x 64 x 64
            nn.Tanh(),
        )

    def Gnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels,momentum=0.9),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img = 3, features_d = 64):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            # _block(in_channels, out_channels, kernel_size, stride, padding)
            self.Dnet(features_d, features_d * 2, 4, 2, 1),
            self.Dnet(features_d * 2, features_d * 4, 4, 2, 1),
            self.Dnet(features_d * 4, features_d * 8, 4, 2, 1),
            # After all _block img output is 4x4 (Conv2d below makes into 1x1)
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
            nn.Sigmoid(),
        )

    def Dnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            #nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
def initialize_weights(model):
    # Initialize weights according to the DCGAN paper
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
#Intitating instances
gen = Generator().to(device)
disc = Discriminator().to(device)
initialize_weights(gen)
initialize_weights(disc)
lr = 2e-4

# %%
optimGenerator = optim.Adam(gen.parameters(), lr=lr, betas=(0.5, 0.999))
optimDiscriminator = optim.Adam(disc.parameters(), lr=lr, betas=(0.5, 0.999))
criterion = nn.BCELoss()
fixed_noise = torch.randn(32, 100, 1, 1).to(device)
step = 0

# %%
gen.train()
disc.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#     (6): Sigmoid()
#   )
# )

# %%
#training block
GenLoss = []
DiscLoss = []
img_list = []
iters = 0

print("!!Training Started!!")
# start timing
time_start = time.time()
num_epochs = 50
for epoch in range(num_epochs):
    epoch = epoch+1
    
#     for batch_idx, (real, _) in enumerate(dataloader):

    for batch_idx, data in enumerate(dataloader,0):
        #training with real batch
        real = data[0].to(device)
        noise = torch.randn(128, 100, 1, 1).to(device)
        fake = gen(noise) #genrator img data

        ### Train Discriminator: max log(D(x)) + log(1 - D(G(z)))
        disc_real = disc(real).reshape(-1)
        loss_disc_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake.detach()).reshape(-1)
        loss_disc_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        loss_disc = (loss_disc_real + loss_disc_fake) / 2
        disc.zero_grad()
        loss_disc.backward()
        optimDiscriminator.step()

        ### Train Generator: min log(1 - D(G(z))) <-> max log(D(G(z))
        output = disc(fake).reshape(-1)
        loss_gen = criterion(output, torch.ones_like(output))
        gen.zero_grad()
        loss_gen.backward()
        optimGenerator.step()

        # Print losses occasionally and print to tensorboard
        if batch_idx % 100 == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(dataloader)} \
                  Loss Discriminator: {loss_disc:.3f}, loss Generator: {loss_gen:.3f}"
            )
        #saving the losses for every 100 batch
        GenLoss.append(loss_gen.detach().cpu())
        DiscLoss.append(loss_disc.detach().cpu())
        
        # Check how the generator is doing by saving G's output on fixed_noise
        if (iters % 500 == 0) or ((epoch == num_epochs) and (batch_idx == len(dataloader)-1)):
            with torch.no_grad():
                fake = gen(fixed_noise).detach().cpu()
            img_list.append(utils.make_grid(fake, padding=2, normalize=True))
            
        iters += 1
        
        
time_end = time.time()
print('elapsed time：%.2f s.'%(time_end-time_start))
# Out:
# !!Training Started!!
# Epoch [1/10] Batch 0/1563                   Loss Discriminator: 0.692, loss Generator: 0.719
# Epoch [1/10] Batch 100/1563                   Loss Discriminator: 0.042, loss Generator: 5.086
# Epoch [1/10] Batch 200/1563                   Loss Discriminator: 0.204, loss Generator: 4.402
# Epoch [1/10] Batch 300/1563                   Loss Discriminator: 0.511, loss Generator: 3.480
# Epoch [1/10] Batch 400/1563                   Loss Discriminator: 0.430, loss Generator: 1.389
# Epoch [1/10] Batch 500/1563                   Loss Discriminator: 0.462, loss Generator: 1.711
# Epoch [1/10] Batch 600/1563                   Loss Discriminator: 0.437, loss Generator: 1.352
# Epoch [1/10] Batch 700/1563                   Loss Discriminator: 0.403, loss Generator: 1.776
# Epoch [1/10] Batch 800/1563                   Loss Discriminator: 0.536, loss Generator: 1.160
# Epoch [1/10] Batch 900/1563                   Loss Discriminator: 0.586, loss Generator: 1.066
# Epoch [1/10] Batch 1000/1563                   Loss Discriminator: 0.685, loss Generator: 0.978
# Epoch [1/10] Batch 1100/1563                   Loss Discriminator: 0.603, loss Generator: 1.129
# Epoch [1/10] Batch 1200/1563                   Loss Discriminator: 0.634, loss Generator: 1.021
# Epoch [1/10] Batch 1300/1563                   Loss Discriminator: 0.719, loss Generator: 0.782
# Epoch [1/10] Batch 1400/1563                   Loss Discriminator: 0.718, loss Generator: 1.106
# Epoch [1/10] Batch 1500/1563                   Loss Discriminator: 0.593, loss Generator: 1.098
# Epoch [2/10] Batch 0/1563                   Loss Discriminator: 0.626, loss Generator: 2.231
# Epoch [2/10] Batch 100/1563                   Loss Discriminator: 0.584, loss Generator: 1.504
# Epoch [2/10] Batch 200/1563                   Loss Discriminator: 0.435, loss Generator: 1.751
# Epoch [2/10] Batch 300/1563                   Loss Discriminator: 0.568, loss Generator: 2.324
# Epoch [2/10] Batch 400/1563                   Loss Discriminator: 0.397, loss Generator: 2.425
# Epoch [2/10] Batch 500/1563                   Loss Discriminator: 0.727, loss Generator: 2.057
# Epoch [2/10] Batch 600/1563                   Loss Discriminator: 0.561, loss Generator: 1.614
# Epoch [2/10] Batch 700/1563                   Loss Discriminator: 0.597, loss Generator: 1.357
# Epoch [2/10] Batch 800/1563                   Loss Discriminator: 0.344, loss Generator: 1.981
# Epoch [2/10] Batch 900/1563                   Loss Discriminator: 0.564, loss Generator: 2.382
# Epoch [2/10] Batch 1000/1563                   Loss Discriminator: 0.495, loss Generator: 1.627
# Epoch [2/10] Batch 1100/1563                   Loss Discriminator: 0.750, loss Generator: 0.898
# Epoch [2/10] Batch 1200/1563                   Loss Discriminator: 0.533, loss Generator: 1.456
# Epoch [2/10] Batch 1300/1563                   Loss Discriminator: 0.646, loss Generator: 1.234
# Epoch [2/10] Batch 1400/1563                   Loss Discriminator: 0.581, loss Generator: 1.204
# Epoch [2/10] Batch 1500/1563                   Loss Discriminator: 0.710, loss Generator: 0.955
# Epoch [3/10] Batch 0/1563                   Loss Discriminator: 0.601, loss Generator: 1.168
# Epoch [3/10] Batch 100/1563                   Loss Discriminator: 0.510, loss Generator: 1.218
# Epoch [3/10] Batch 200/1563                   Loss Discriminator: 0.535, loss Generator: 1.114
# Epoch [3/10] Batch 300/1563                   Loss Discriminator: 0.514, loss Generator: 1.837
# Epoch [3/10] Batch 400/1563                   Loss Discriminator: 0.509, loss Generator: 1.523
# Epoch [3/10] Batch 500/1563                   Loss Discriminator: 0.645, loss Generator: 1.791
# Epoch [3/10] Batch 600/1563                   Loss Discriminator: 0.540, loss Generator: 1.436
# Epoch [3/10] Batch 700/1563                   Loss Discriminator: 0.469, loss Generator: 1.437
# Epoch [3/10] Batch 800/1563                   Loss Discriminator: 0.482, loss Generator: 1.218
# Epoch [3/10] Batch 900/1563                   Loss Discriminator: 0.529, loss Generator: 1.673
# Epoch [3/10] Batch 1000/1563                   Loss Discriminator: 0.594, loss Generator: 1.079
# Epoch [3/10] Batch 1100/1563                   Loss Discriminator: 0.621, loss Generator: 1.158
# Epoch [3/10] Batch 1200/1563                   Loss Discriminator: 0.582, loss Generator: 1.570
# Epoch [3/10] Batch 1300/1563                   Loss Discriminator: 0.558, loss Generator: 1.134
# Epoch [3/10] Batch 1400/1563                   Loss Discriminator: 0.683, loss Generator: 1.296
# Epoch [3/10] Batch 1500/1563                   Loss Discriminator: 0.664, loss Generator: 1.122
# Epoch [4/10] Batch 0/1563                   Loss Discriminator: 0.500, loss Generator: 1.484
# Epoch [4/10] Batch 100/1563                   Loss Discriminator: 0.642, loss Generator: 0.845
# Epoch [4/10] Batch 200/1563                   Loss Discriminator: 0.551, loss Generator: 1.093
# Epoch [4/10] Batch 300/1563                   Loss Discriminator: 0.598, loss Generator: 0.891
# Epoch [4/10] Batch 400/1563                   Loss Discriminator: 0.708, loss Generator: 1.255
# Epoch [4/10] Batch 500/1563                   Loss Discriminator: 0.596, loss Generator: 1.336
# Epoch [4/10] Batch 600/1563                   Loss Discriminator: 0.490, loss Generator: 1.113
# Epoch [4/10] Batch 700/1563                   Loss Discriminator: 0.612, loss Generator: 0.940
# Epoch [4/10] Batch 800/1563                   Loss Discriminator: 0.574, loss Generator: 1.404
# Epoch [4/10] Batch 900/1563                   Loss Discriminator: 0.644, loss Generator: 1.722
# Epoch [4/10] Batch 1000/1563                   Loss Discriminator: 0.661, loss Generator: 1.118
# Epoch [4/10] Batch 1100/1563                   Loss Discriminator: 0.607, loss Generator: 0.944
# Epoch [4/10] Batch 1200/1563                   Loss Discriminator: 0.605, loss Generator: 1.048
# Epoch [4/10] Batch 1300/1563                   Loss Discriminator: 0.587, loss Generator: 1.122
# Epoch [4/10] Batch 1400/1563                   Loss Discriminator: 0.622, loss Generator: 1.226
# Epoch [4/10] Batch 1500/1563                   Loss Discriminator: 0.661, loss Generator: 1.012
# Epoch [5/10] Batch 0/1563                   Loss Discriminator: 0.578, loss Generator: 1.088
# Epoch [5/10] Batch 100/1563                   Loss Discriminator: 0.570, loss Generator: 0.972
# Epoch [5/10] Batch 200/1563                   Loss Discriminator: 0.595, loss Generator: 1.005
# Epoch [5/10] Batch 300/1563                   Loss Discriminator: 0.618, loss Generator: 0.961
# Epoch [5/10] Batch 400/1563                   Loss Discriminator: 0.639, loss Generator: 0.928
# Epoch [5/10] Batch 500/1563                   Loss Discriminator: 0.607, loss Generator: 1.006
# Epoch [5/10] Batch 600/1563                   Loss Discriminator: 0.645, loss Generator: 0.894
# Epoch [5/10] Batch 700/1563                   Loss Discriminator: 0.541, loss Generator: 1.000
# Epoch [5/10] Batch 800/1563                   Loss Discriminator: 0.609, loss Generator: 0.854
# Epoch [5/10] Batch 900/1563                   Loss Discriminator: 0.652, loss Generator: 0.920
# Epoch [5/10] Batch 1000/1563                   Loss Discriminator: 0.648, loss Generator: 0.856
# Epoch [5/10] Batch 1100/1563                   Loss Discriminator: 0.656, loss Generator: 0.955
# Epoch [5/10] Batch 1200/1563                   Loss Discriminator: 0.582, loss Generator: 0.990
# Epoch [5/10] Batch 1300/1563                   Loss Discriminator: 0.577, loss Generator: 0.976
# Epoch [5/10] Batch 1400/1563                   Loss Discriminator: 0.686, loss Generator: 0.931
# Epoch [5/10] Batch 1500/1563                   Loss Discriminator: 0.641, loss Generator: 1.058
# Epoch [6/10] Batch 0/1563                   Loss Discriminator: 0.605, loss Generator: 0.982
# Epoch [6/10] Batch 100/1563                   Loss Discriminator: 0.627, loss Generator: 0.878
# Epoch [6/10] Batch 200/1563                   Loss Discriminator: 0.606, loss Generator: 0.995
# Epoch [6/10] Batch 300/1563                   Loss Discriminator: 0.650, loss Generator: 0.992
# Epoch [6/10] Batch 400/1563                   Loss Discriminator: 0.569, loss Generator: 1.031
# Epoch [6/10] Batch 500/1563                   Loss Discriminator: 0.612, loss Generator: 0.866
# Epoch [6/10] Batch 600/1563                   Loss Discriminator: 0.604, loss Generator: 0.804
# Epoch [6/10] Batch 700/1563                   Loss Discriminator: 0.676, loss Generator: 0.949
# Epoch [6/10] Batch 800/1563                   Loss Discriminator: 0.647, loss Generator: 0.889
# Epoch [6/10] Batch 900/1563                   Loss Discriminator: 0.724, loss Generator: 1.104
# Epoch [6/10] Batch 1000/1563                   Loss Discriminator: 0.626, loss Generator: 0.849
# Epoch [6/10] Batch 1100/1563                   Loss Discriminator: 0.679, loss Generator: 1.109
# Epoch [6/10] Batch 1200/1563                   Loss Discriminator: 0.618, loss Generator: 1.029
# Epoch [6/10] Batch 1300/1563                   Loss Discriminator: 0.673, loss Generator: 1.235
# Epoch [6/10] Batch 1400/1563                   Loss Discriminator: 0.625, loss Generator: 1.107
# Epoch [6/10] Batch 1500/1563                   Loss Discriminator: 0.634, loss Generator: 1.071
# Epoch [7/10] Batch 0/1563                   Loss Discriminator: 0.632, loss Generator: 0.836
# Epoch [7/10] Batch 100/1563                   Loss Discriminator: 0.642, loss Generator: 0.898
# Epoch [7/10] Batch 200/1563                   Loss Discriminator: 0.587, loss Generator: 0.921
# Epoch [7/10] Batch 300/1563                   Loss Discriminator: 0.634, loss Generator: 0.854
# Epoch [7/10] Batch 400/1563                   Loss Discriminator: 0.577, loss Generator: 1.162
# Epoch [7/10] Batch 500/1563                   Loss Discriminator: 0.765, loss Generator: 0.989
# Epoch [7/10] Batch 600/1563                   Loss Discriminator: 0.625, loss Generator: 0.909
# Epoch [7/10] Batch 700/1563                   Loss Discriminator: 0.667, loss Generator: 0.792
# Epoch [7/10] Batch 800/1563                   Loss Discriminator: 0.640, loss Generator: 1.090
# Epoch [7/10] Batch 900/1563                   Loss Discriminator: 0.600, loss Generator: 0.961
# Epoch [7/10] Batch 1000/1563                   Loss Discriminator: 0.728, loss Generator: 0.962
# Epoch [7/10] Batch 1100/1563                   Loss Discriminator: 0.639, loss Generator: 0.782
# Epoch [7/10] Batch 1200/1563                   Loss Discriminator: 0.542, loss Generator: 1.146
# Epoch [7/10] Batch 1300/1563                   Loss Discriminator: 0.589, loss Generator: 1.066
# Epoch [7/10] Batch 1400/1563                   Loss Discriminator: 0.596, loss Generator: 0.844
# Epoch [7/10] Batch 1500/1563                   Loss Discriminator: 0.666, loss Generator: 0.885
# Epoch [8/10] Batch 0/1563                   Loss Discriminator: 0.657, loss Generator: 1.047
# Epoch [8/10] Batch 100/1563                   Loss Discriminator: 0.554, loss Generator: 1.483
# Epoch [8/10] Batch 200/1563                   Loss Discriminator: 0.555, loss Generator: 1.013
# Epoch [8/10] Batch 300/1563                   Loss Discriminator: 0.541, loss Generator: 1.389
# Epoch [8/10] Batch 400/1563                   Loss Discriminator: 0.604, loss Generator: 1.162
# Epoch [8/10] Batch 500/1563                   Loss Discriminator: 0.551, loss Generator: 1.028
# Epoch [8/10] Batch 600/1563                   Loss Discriminator: 0.698, loss Generator: 0.808
# Epoch [8/10] Batch 700/1563                   Loss Discriminator: 0.643, loss Generator: 0.705
# Epoch [8/10] Batch 800/1563                   Loss Discriminator: 0.498, loss Generator: 0.825
# Epoch [8/10] Batch 900/1563                   Loss Discriminator: 0.500, loss Generator: 1.056
# Epoch [8/10] Batch 1000/1563                   Loss Discriminator: 0.602, loss Generator: 0.860
# Epoch [8/10] Batch 1100/1563                   Loss Discriminator: 0.668, loss Generator: 1.180
# Epoch [8/10] Batch 1200/1563                   Loss Discriminator: 0.587, loss Generator: 1.271
# Epoch [8/10] Batch 1300/1563                   Loss Discriminator: 0.495, loss Generator: 1.181
# Epoch [8/10] Batch 1400/1563                   Loss Discriminator: 0.468, loss Generator: 1.111
# Epoch [8/10] Batch 1500/1563                   Loss Discriminator: 0.586, loss Generator: 0.734
# Epoch [9/10] Batch 0/1563                   Loss Discriminator: 0.584, loss Generator: 1.441
# Epoch [9/10] Batch 100/1563                   Loss Discriminator: 0.495, loss Generator: 2.529
# Epoch [9/10] Batch 200/1563                   Loss Discriminator: 0.531, loss Generator: 1.160
# Epoch [9/10] Batch 300/1563                   Loss Discriminator: 0.711, loss Generator: 0.915
# Epoch [9/10] Batch 400/1563                   Loss Discriminator: 0.542, loss Generator: 1.125
# Epoch [9/10] Batch 500/1563                   Loss Discriminator: 0.590, loss Generator: 1.321
# Epoch [9/10] Batch 600/1563                   Loss Discriminator: 0.485, loss Generator: 1.093
# Epoch [9/10] Batch 700/1563                   Loss Discriminator: 0.551, loss Generator: 1.831
# Epoch [9/10] Batch 800/1563                   Loss Discriminator: 0.577, loss Generator: 1.408
# Epoch [9/10] Batch 900/1563                   Loss Discriminator: 0.496, loss Generator: 1.284
# Epoch [9/10] Batch 1000/1563                   Loss Discriminator: 0.469, loss Generator: 1.419
# Epoch [9/10] Batch 1100/1563                   Loss Discriminator: 0.423, loss Generator: 1.205
# Epoch [9/10] Batch 1200/1563                   Loss Discriminator: 0.459, loss Generator: 1.243
# Epoch [9/10] Batch 1300/1563                   Loss Discriminator: 0.517, loss Generator: 1.000
# Epoch [9/10] Batch 1400/1563                   Loss Discriminator: 0.421, loss Generator: 1.449
# Epoch [9/10] Batch 1500/1563                   Loss Discriminator: 0.508, loss Generator: 1.174
# Epoch [10/10] Batch 0/1563                   Loss Discriminator: 0.444, loss Generator: 1.116
# Epoch [10/10] Batch 100/1563                   Loss Discriminator: 0.444, loss Generator: 2.581
# Epoch [10/10] Batch 200/1563                   Loss Discriminator: 0.494, loss Generator: 1.157
# Epoch [10/10] Batch 300/1563                   Loss Discriminator: 0.495, loss Generator: 1.666
# Epoch [10/10] Batch 400/1563                   Loss Discriminator: 0.592, loss Generator: 0.813
# Epoch [10/10] Batch 500/1563                   Loss Discriminator: 0.490, loss Generator: 1.464
# Epoch [10/10] Batch 600/1563                   Loss Discriminator: 0.509, loss Generator: 1.062
# Epoch [10/10] Batch 700/1563                   Loss Discriminator: 0.697, loss Generator: 0.657
# Epoch [10/10] Batch 800/1563                   Loss Discriminator: 0.616, loss Generator: 1.035
# Epoch [10/10] Batch 900/1563                   Loss Discriminator: 0.460, loss Generator: 1.694
# Epoch [10/10] Batch 1000/1563                   Loss Discriminator: 0.546, loss Generator: 0.878
# Epoch [10/10] Batch 1100/1563                   Loss Discriminator: 0.392, loss Generator: 1.333
# Epoch [10/10] Batch 1200/1563                   Loss Discriminator: 0.484, loss Generator: 1.592
# Epoch [10/10] Batch 1300/1563                   Loss Discriminator: 0.426, loss Generator: 1.358
# Epoch [10/10] Batch 1400/1563                   Loss Discriminator: 0.476, loss Generator: 1.156
# Epoch [10/10] Batch 1500/1563                   Loss Discriminator: 0.485, loss Generator: 1.201
# elapsed time：1290.42 s.

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(GenLoss,label="Gen")
plt.plot(DiscLoss,label="Disc")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in img_list]
ani = animation.ArtistAnimation(fig, ims, interval=1000, repeat_delay=1000, blit=True)

# %%
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

# Plot the fake images from the last epoch
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.show()
