# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
torch.manual_seed(1)

# %%
def load_data(train_batch_size, test_batch_size):
    # Fetch training data: total 60000 samples
        
    trainset = datasets.MNIST('data', train = True, download = False, 
                transform = transforms.Compose([
                transforms.Resize((32,32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    temp = torch.tensor(np.random.randint(0, 10, (len(trainset)),))
    print(temp)
    trainset.targets = temp
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=train_batch_size, shuffle=True)

    testset = datasets.MNIST('data', train = False, 
                transform = transforms.Compose([
                transforms.Resize((32, 32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    test_loader = torch.utils.data.DataLoader(testset ,batch_size = test_batch_size, shuffle=True)

    return (train_loader, test_loader)

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = self.fc3(x)
        return x

# %%
train_batch_size = 100
test_batch_size = 100
train_loader, test_loader = load_data(train_batch_size, test_batch_size)
# Out:
# tensor([6, 1, 6,  ..., 4, 7, 5], dtype=torch.int32)

# %%
def train(model, optimizer, epoch, train_loader, log_interval):
    model.train()
    loss_fn = torch.nn.CrossEntropyLoss()
    n_correct = 0
    n_samples = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()

        optimizer.step()

        _, predicted = torch.max(output.data, 1)
        n_samples += target.size(0)
        n_correct += (predicted == target).sum().item()
        acc = 100.0 * n_correct / n_samples
        # print log
        
        if batch_idx % log_interval == 0:
            print('Train set, Epoch {} [{}/{}]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                loss.data))
            print("Train Accuracy: ", round(acc,2))
    return loss.data, round(acc,2)

# %%
def test(model, epoch, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    
    loss_fn = torch.nn.CrossEntropyLoss(size_average=False)

    for data, target in test_loader:
        data, target = Variable(data), Variable(target)
        
        output = model(data)
        loss = loss_fn(output, target)
        test_loss = test_loss + loss.data

        pred = np.argmax(output.data, axis = 1)
        correct = correct + np.equal(pred, target.data).sum()

    # Print log
    test_loss /= len(test_loader.dataset)
    print('\nTest set, Epoch {} , Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch,
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss

# %%
model = LeNet()

optimizer = optim.Adam(model.parameters(), lr=0.0001)
m1_train_loss_arr = []
m1_test_loss_arr = []

epochs = 100
log_interval = 500
for epoch in range(1, epochs + 1):
    loss, acc = train(model, optimizer, epoch, train_loader, log_interval)
    m1_train_loss_arr.append(loss)
    loss_test = test(model, epoch, test_loader)
    m1_test_loss_arr.append(loss_test)
# Out:
# Train set, Epoch 1 [0/60000]	Loss: 2.304834
# Train Accuracy:  13.0
# Train set, Epoch 1 [50000/60000]	Loss: 2.304742
# Train Accuracy:  10.05
# C:\Users\nikhi\anaconda3\envs\deeplearning\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set, Epoch 1 , Average loss: 2.3041, Accuracy: 1098/10000 (11%)
#
# Train set, Epoch 2 [0/60000]	Loss: 2.304913
# Train Accuracy:  12.0
# Train set, Epoch 2 [50000/60000]	Loss: 2.306288
# Train Accuracy:  10.39
#
# Test set, Epoch 2 , Average loss: 2.3039, Accuracy: 1039/10000 (10%)
#
# Train set, Epoch 3 [0/60000]	Loss: 2.308414
# Train Accuracy:  5.0
# Train set, Epoch 3 [50000/60000]	Loss: 2.302626
# Train Accuracy:  10.67
#
# Test set, Epoch 3 , Average loss: 2.3030, Accuracy: 1011/10000 (10%)
#
# Train set, Epoch 4 [0/60000]	Loss: 2.298389
# Train Accuracy:  10.0
# Train set, Epoch 4 [50000/60000]	Loss: 2.296143
# Train Accuracy:  10.81
#
# Test set, Epoch 4 , Average loss: 2.3021, Accuracy: 1237/10000 (12%)
#
# Train set, Epoch 5 [0/60000]	Loss: 2.301450
# Train Accuracy:  8.0
# Train set, Epoch 5 [50000/60000]	Loss: 2.306586
# Train Accuracy:  10.89
#
# Test set, Epoch 5 , Average loss: 2.2998, Accuracy: 1055/10000 (11%)
#
# Train set, Epoch 6 [0/60000]	Loss: 2.296106
# Train Accuracy:  15.0
# Train set, Epoch 6 [50000/60000]	Loss: 2.301628
# Train Accuracy:  11.05
#
# Test set, Epoch 6 , Average loss: 2.3007, Accuracy: 1078/10000 (11%)
#
# Train set, Epoch 7 [0/60000]	Loss: 2.298397
# Train Accuracy:  10.0
# Train set, Epoch 7 [50000/60000]	Loss: 2.296345
# Train Accuracy:  11.24
#
# Test set, Epoch 7 , Average loss: 2.3010, Accuracy: 1023/10000 (10%)
#
# Train set, Epoch 8 [0/60000]	Loss: 2.292434
# Train Accuracy:  13.0
# Train set, Epoch 8 [50000/60000]	Loss: 2.303871
# Train Accuracy:  11.52
#
# Test set, Epoch 8 , Average loss: 2.3026, Accuracy: 1003/10000 (10%)
#
# Train set, Epoch 9 [0/60000]	Loss: 2.306355
# Train Accuracy:  15.0
# Train set, Epoch 9 [50000/60000]	Loss: 2.295130
# Train Accuracy:  11.88
#
# Test set, Epoch 9 , Average loss: 2.2915, Accuracy: 1340/10000 (13%)
#
# Train set, Epoch 10 [0/60000]	Loss: 2.285311
# Train Accuracy:  18.0
# Train set, Epoch 10 [50000/60000]	Loss: 2.296422
# Train Accuracy:  11.98
#
# Test set, Epoch 10 , Average loss: 2.2926, Accuracy: 1339/10000 (13%)
#
# Train set, Epoch 11 [0/60000]	Loss: 2.299588
# Train Accuracy:  9.0
# Train set, Epoch 11 [50000/60000]	Loss: 2.297358
# Train Accuracy:  12.35
#
# Test set, Epoch 11 , Average loss: 2.3054, Accuracy: 1053/10000 (11%)
#
# Train set, Epoch 12 [0/60000]	Loss: 2.287184
# Train Accuracy:  14.0
# Train set, Epoch 12 [50000/60000]	Loss: 2.302223
# Train Accuracy:  12.44
#
# Test set, Epoch 12 , Average loss: 2.3006, Accuracy: 1214/10000 (12%)
#
# Train set, Epoch 13 [0/60000]	Loss: 2.295857
# Train Accuracy:  14.0
# Train set, Epoch 13 [50000/60000]	Loss: 2.272968
# Train Accuracy:  12.73
#
# Test set, Epoch 13 , Average loss: 2.2970, Accuracy: 1151/10000 (12%)
#
# Train set, Epoch 14 [0/60000]	Loss: 2.308017
# Train Accuracy:  6.0
# Train set, Epoch 14 [50000/60000]	Loss: 2.287216
# Train Accuracy:  12.92
#
# Test set, Epoch 14 , Average loss: 2.3050, Accuracy: 1088/10000 (11%)
#
# Train set, Epoch 15 [0/60000]	Loss: 2.304785
# Train Accuracy:  8.0
# Train set, Epoch 15 [50000/60000]	Loss: 2.266936
# Train Accuracy:  13.14
#
# Test set, Epoch 15 , Average loss: 2.3048, Accuracy: 949/10000 (9%)
#
# Train set, Epoch 16 [0/60000]	Loss: 2.280667
# Train Accuracy:  11.0
# Train set, Epoch 16 [50000/60000]	Loss: 2.263155
# Train Accuracy:  13.65
#
# Test set, Epoch 16 , Average loss: 2.3020, Accuracy: 1062/10000 (11%)
#
# Train set, Epoch 17 [0/60000]	Loss: 2.290549
# Train Accuracy:  16.0
# Train set, Epoch 17 [50000/60000]	Loss: 2.282439
# Train Accuracy:  13.77
#
# Test set, Epoch 17 , Average loss: 2.3024, Accuracy: 1115/10000 (11%)
#
# Train set, Epoch 18 [0/60000]	Loss: 2.264552
# Train Accuracy:  11.0
# Train set, Epoch 18 [50000/60000]	Loss: 2.290951
# Train Accuracy:  14.27
#
# Test set, Epoch 18 , Average loss: 2.2958, Accuracy: 1217/10000 (12%)
#
# Train set, Epoch 19 [0/60000]	Loss: 2.277357
# Train Accuracy:  10.0
# Train set, Epoch 19 [50000/60000]	Loss: 2.281234
# Train Accuracy:  14.46
#
# Test set, Epoch 19 , Average loss: 2.2950, Accuracy: 1459/10000 (15%)
#
# Train set, Epoch 20 [0/60000]	Loss: 2.243094
# Train Accuracy:  19.0
# Train set, Epoch 20 [50000/60000]	Loss: 2.284170
# Train Accuracy:  14.66
#
# Test set, Epoch 20 , Average loss: 2.2922, Accuracy: 1314/10000 (13%)
#
# Train set, Epoch 21 [0/60000]	Loss: 2.260317
# Train Accuracy:  14.0
# Train set, Epoch 21 [50000/60000]	Loss: 2.264045
# Train Accuracy:  14.83
#
# Test set, Epoch 21 , Average loss: 2.3048, Accuracy: 1051/10000 (11%)
#
# Train set, Epoch 22 [0/60000]	Loss: 2.248666
# Train Accuracy:  13.0
# Train set, Epoch 22 [50000/60000]	Loss: 2.254748
# Train Accuracy:  14.99
#
# Test set, Epoch 22 , Average loss: 2.3139, Accuracy: 1126/10000 (11%)
#
# Train set, Epoch 23 [0/60000]	Loss: 2.260660
# Train Accuracy:  20.0
# Train set, Epoch 23 [50000/60000]	Loss: 2.277304
# Train Accuracy:  15.35
#
# Test set, Epoch 23 , Average loss: 2.3128, Accuracy: 1137/10000 (11%)
#
# Train set, Epoch 24 [0/60000]	Loss: 2.267236
# Train Accuracy:  17.0
# Train set, Epoch 24 [50000/60000]	Loss: 2.255245
# Train Accuracy:  15.67
#
# Test set, Epoch 24 , Average loss: 2.3257, Accuracy: 1058/10000 (11%)
#
# Train set, Epoch 25 [0/60000]	Loss: 2.287521
# Train Accuracy:  11.0
# Train set, Epoch 25 [50000/60000]	Loss: 2.282570
# Train Accuracy:  15.8
#
# Test set, Epoch 25 , Average loss: 2.3259, Accuracy: 982/10000 (10%)
#
# Train set, Epoch 26 [0/60000]	Loss: 2.250886
# Train Accuracy:  18.0
# Train set, Epoch 26 [50000/60000]	Loss: 2.254201
# Train Accuracy:  16.19
#
# Test set, Epoch 26 , Average loss: 2.2992, Accuracy: 1307/10000 (13%)
#
# Train set, Epoch 27 [0/60000]	Loss: 2.236605
# Train Accuracy:  20.0
# Train set, Epoch 27 [50000/60000]	Loss: 2.271559
# Train Accuracy:  16.5
#
# Test set, Epoch 27 , Average loss: 2.3126, Accuracy: 1080/10000 (11%)
#
# Train set, Epoch 28 [0/60000]	Loss: 2.277071
# Train Accuracy:  11.0
# Train set, Epoch 28 [50000/60000]	Loss: 2.226577
# Train Accuracy:  16.55
#
# Test set, Epoch 28 , Average loss: 2.3121, Accuracy: 1275/10000 (13%)
#
# Train set, Epoch 29 [0/60000]	Loss: 2.221482
# Train Accuracy:  21.0
# Train set, Epoch 29 [50000/60000]	Loss: 2.240277
# Train Accuracy:  17.18
#
# Test set, Epoch 29 , Average loss: 2.3250, Accuracy: 1223/10000 (12%)
#
# Train set, Epoch 30 [0/60000]	Loss: 2.221092
# Train Accuracy:  12.0
# Train set, Epoch 30 [50000/60000]	Loss: 2.201741
# Train Accuracy:  17.07
#
# Test set, Epoch 30 , Average loss: 2.3276, Accuracy: 1149/10000 (11%)
#
# Train set, Epoch 31 [0/60000]	Loss: 2.266646
# Train Accuracy:  13.0
# Train set, Epoch 31 [50000/60000]	Loss: 2.234000
# Train Accuracy:  17.43
#
# Test set, Epoch 31 , Average loss: 2.3250, Accuracy: 1145/10000 (11%)
#
# Train set, Epoch 32 [0/60000]	Loss: 2.233140
# Train Accuracy:  20.0
# Train set, Epoch 32 [50000/60000]	Loss: 2.179083
# Train Accuracy:  17.72
#
# Test set, Epoch 32 , Average loss: 2.3271, Accuracy: 1383/10000 (14%)
#
# Train set, Epoch 33 [0/60000]	Loss: 2.239667
# Train Accuracy:  18.0
# Train set, Epoch 33 [50000/60000]	Loss: 2.237288
# Train Accuracy:  17.81
#
# Test set, Epoch 33 , Average loss: 2.3289, Accuracy: 1191/10000 (12%)
#
# Train set, Epoch 34 [0/60000]	Loss: 2.186818
# Train Accuracy:  21.0
# Train set, Epoch 34 [50000/60000]	Loss: 2.283707
# Train Accuracy:  17.97
#
# Test set, Epoch 34 , Average loss: 2.3690, Accuracy: 1005/10000 (10%)
#
# Train set, Epoch 35 [0/60000]	Loss: 2.215224
# Train Accuracy:  17.0
# Train set, Epoch 35 [50000/60000]	Loss: 2.141464
# Train Accuracy:  18.49
#
# Test set, Epoch 35 , Average loss: 2.3773, Accuracy: 955/10000 (10%)
#
# Train set, Epoch 36 [0/60000]	Loss: 2.213830
# Train Accuracy:  13.0
# Train set, Epoch 36 [50000/60000]	Loss: 2.276384
# Train Accuracy:  18.78
#
# Test set, Epoch 36 , Average loss: 2.3389, Accuracy: 1198/10000 (12%)
#
# Train set, Epoch 37 [0/60000]	Loss: 2.160681
# Train Accuracy:  20.0
# Train set, Epoch 37 [50000/60000]	Loss: 2.194734
# Train Accuracy:  18.67
#
# Test set, Epoch 37 , Average loss: 2.3457, Accuracy: 1189/10000 (12%)
#
# Train set, Epoch 38 [0/60000]	Loss: 2.202044
# Train Accuracy:  17.0
# Train set, Epoch 38 [50000/60000]	Loss: 2.220248
# Train Accuracy:  19.05
#
# Test set, Epoch 38 , Average loss: 2.3509, Accuracy: 1248/10000 (12%)
#
# Train set, Epoch 39 [0/60000]	Loss: 2.206701
# Train Accuracy:  19.0
# Train set, Epoch 39 [50000/60000]	Loss: 2.142923
# Train Accuracy:  19.38
#
# Test set, Epoch 39 , Average loss: 2.3676, Accuracy: 1141/10000 (11%)
#
# Train set, Epoch 40 [0/60000]	Loss: 2.221029
# Train Accuracy:  19.0
# Train set, Epoch 40 [50000/60000]	Loss: 2.208754
# Train Accuracy:  19.56
#
# Test set, Epoch 40 , Average loss: 2.3593, Accuracy: 1146/10000 (11%)
#
# Train set, Epoch 41 [0/60000]	Loss: 2.158546
# Train Accuracy:  21.0
# Train set, Epoch 41 [50000/60000]	Loss: 2.230921
# Train Accuracy:  19.84
#
# Test set, Epoch 41 , Average loss: 2.3975, Accuracy: 1125/10000 (11%)
#
# Train set, Epoch 42 [0/60000]	Loss: 2.181371
# Train Accuracy:  25.0
# Train set, Epoch 42 [50000/60000]	Loss: 2.200449
# Train Accuracy:  19.93
#
# Test set, Epoch 42 , Average loss: 2.3753, Accuracy: 1085/10000 (11%)
#
# Train set, Epoch 43 [0/60000]	Loss: 2.167303
# Train Accuracy:  26.0
# Train set, Epoch 43 [50000/60000]	Loss: 2.172080
# Train Accuracy:  20.11
#
# Test set, Epoch 43 , Average loss: 2.3999, Accuracy: 1067/10000 (11%)
#
# Train set, Epoch 44 [0/60000]	Loss: 2.127101
# Train Accuracy:  24.0
# Train set, Epoch 44 [50000/60000]	Loss: 2.143865
# Train Accuracy:  20.32
#
# Test set, Epoch 44 , Average loss: 2.3997, Accuracy: 1077/10000 (11%)
#
# Train set, Epoch 45 [0/60000]	Loss: 2.214154
# Train Accuracy:  18.0
# Train set, Epoch 45 [50000/60000]	Loss: 2.235058
# Train Accuracy:  20.4
#
# Test set, Epoch 45 , Average loss: 2.4241, Accuracy: 1008/10000 (10%)
#
# Train set, Epoch 46 [0/60000]	Loss: 2.152153
# Train Accuracy:  20.0
# Train set, Epoch 46 [50000/60000]	Loss: 2.250568
# Train Accuracy:  21.03
#
# Test set, Epoch 46 , Average loss: 2.4035, Accuracy: 1126/10000 (11%)
#
# Train set, Epoch 47 [0/60000]	Loss: 2.175004
# Train Accuracy:  21.0
# Train set, Epoch 47 [50000/60000]	Loss: 2.155881
# Train Accuracy:  21.0
#
# Test set, Epoch 47 , Average loss: 2.3997, Accuracy: 1172/10000 (12%)
#
# Train set, Epoch 48 [0/60000]	Loss: 2.227751
# Train Accuracy:  24.0
# Train set, Epoch 48 [50000/60000]	Loss: 2.106002
# Train Accuracy:  21.29
#
# Test set, Epoch 48 , Average loss: 2.4429, Accuracy: 1025/10000 (10%)
#
# Train set, Epoch 49 [0/60000]	Loss: 2.104854
# Train Accuracy:  26.0
# Train set, Epoch 49 [50000/60000]	Loss: 2.145459
# Train Accuracy:  21.53
#
# Test set, Epoch 49 , Average loss: 2.3975, Accuracy: 1184/10000 (12%)
#
# Train set, Epoch 50 [0/60000]	Loss: 2.137261
# Train Accuracy:  25.0
# Train set, Epoch 50 [50000/60000]	Loss: 2.122480
# Train Accuracy:  21.64
#
# Test set, Epoch 50 , Average loss: 2.3960, Accuracy: 1254/10000 (13%)
#
# Train set, Epoch 51 [0/60000]	Loss: 2.115389
# Train Accuracy:  23.0
# Train set, Epoch 51 [50000/60000]	Loss: 2.126656
# Train Accuracy:  21.82
#
# Test set, Epoch 51 , Average loss: 2.3767, Accuracy: 1315/10000 (13%)
#
# Train set, Epoch 52 [0/60000]	Loss: 2.179618
# Train Accuracy:  20.0
# Train set, Epoch 52 [50000/60000]	Loss: 2.100558
# Train Accuracy:  21.91
#
# Test set, Epoch 52 , Average loss: 2.3994, Accuracy: 1210/10000 (12%)
#
# Train set, Epoch 53 [0/60000]	Loss: 2.102849
# Train Accuracy:  30.0
# Train set, Epoch 53 [50000/60000]	Loss: 2.178688
# Train Accuracy:  22.25
#
# Test set, Epoch 53 , Average loss: 2.4152, Accuracy: 1185/10000 (12%)
#
# Train set, Epoch 54 [0/60000]	Loss: 2.065000
# Train Accuracy:  25.0
# Train set, Epoch 54 [50000/60000]	Loss: 2.188569
# Train Accuracy:  22.48
#
# Test set, Epoch 54 , Average loss: 2.4490, Accuracy: 1050/10000 (10%)
#
# Train set, Epoch 55 [0/60000]	Loss: 2.147496
# Train Accuracy:  21.0
# Train set, Epoch 55 [50000/60000]	Loss: 2.152786
# Train Accuracy:  22.35
#
# Test set, Epoch 55 , Average loss: 2.4485, Accuracy: 1030/10000 (10%)
#
# Train set, Epoch 56 [0/60000]	Loss: 2.194278
# Train Accuracy:  18.0
# Train set, Epoch 56 [50000/60000]	Loss: 2.122363
# Train Accuracy:  22.81
#
# Test set, Epoch 56 , Average loss: 2.4323, Accuracy: 1245/10000 (12%)
#
# Train set, Epoch 57 [0/60000]	Loss: 2.078132
# Train Accuracy:  30.0
# Train set, Epoch 57 [50000/60000]	Loss: 2.161028
# Train Accuracy:  22.96
#
# Test set, Epoch 57 , Average loss: 2.4024, Accuracy: 1281/10000 (13%)
#
# Train set, Epoch 58 [0/60000]	Loss: 2.167112
# Train Accuracy:  24.0
# Train set, Epoch 58 [50000/60000]	Loss: 2.042067
# Train Accuracy:  23.18
#
# Test set, Epoch 58 , Average loss: 2.4705, Accuracy: 1124/10000 (11%)
#
# Train set, Epoch 59 [0/60000]	Loss: 2.104455
# Train Accuracy:  25.0
# Train set, Epoch 59 [50000/60000]	Loss: 2.041708
# Train Accuracy:  23.07
#
# Test set, Epoch 59 , Average loss: 2.4838, Accuracy: 964/10000 (10%)
#
# Train set, Epoch 60 [0/60000]	Loss: 2.070995
# Train Accuracy:  26.0
# Train set, Epoch 60 [50000/60000]	Loss: 2.156146
# Train Accuracy:  23.57
#
# Test set, Epoch 60 , Average loss: 2.4539, Accuracy: 1208/10000 (12%)
#
# Train set, Epoch 61 [0/60000]	Loss: 2.070870
# Train Accuracy:  22.0
# Train set, Epoch 61 [50000/60000]	Loss: 2.066411
# Train Accuracy:  23.71
#
# Test set, Epoch 61 , Average loss: 2.4617, Accuracy: 1108/10000 (11%)
#
# Train set, Epoch 62 [0/60000]	Loss: 1.957983
# Train Accuracy:  32.0
# Train set, Epoch 62 [50000/60000]	Loss: 2.158647
# Train Accuracy:  23.85
#
# Test set, Epoch 62 , Average loss: 2.4791, Accuracy: 1036/10000 (10%)
#
# Train set, Epoch 63 [0/60000]	Loss: 2.139056
# Train Accuracy:  23.0
# Train set, Epoch 63 [50000/60000]	Loss: 2.154634
# Train Accuracy:  23.94
#
# Test set, Epoch 63 , Average loss: 2.4503, Accuracy: 1195/10000 (12%)
#
# Train set, Epoch 64 [0/60000]	Loss: 2.147722
# Train Accuracy:  21.0
# Train set, Epoch 64 [50000/60000]	Loss: 2.123195
# Train Accuracy:  24.17
#
# Test set, Epoch 64 , Average loss: 2.5030, Accuracy: 1077/10000 (11%)
#
# Train set, Epoch 65 [0/60000]	Loss: 2.031788
# Train Accuracy:  24.0
# Train set, Epoch 65 [50000/60000]	Loss: 2.154960
# Train Accuracy:  24.62
#
# Test set, Epoch 65 , Average loss: 2.4287, Accuracy: 1279/10000 (13%)
#
# Train set, Epoch 66 [0/60000]	Loss: 2.031344
# Train Accuracy:  24.0
# Train set, Epoch 66 [50000/60000]	Loss: 2.065162
# Train Accuracy:  24.49
#
# Test set, Epoch 66 , Average loss: 2.4963, Accuracy: 1059/10000 (11%)
#
# Train set, Epoch 67 [0/60000]	Loss: 2.103726
# Train Accuracy:  21.0
# Train set, Epoch 67 [50000/60000]	Loss: 2.044176
# Train Accuracy:  24.77
#
# Test set, Epoch 67 , Average loss: 2.4937, Accuracy: 1069/10000 (11%)
#
# Train set, Epoch 68 [0/60000]	Loss: 2.062696
# Train Accuracy:  26.0
# Train set, Epoch 68 [50000/60000]	Loss: 2.156477
# Train Accuracy:  24.83
#
# Test set, Epoch 68 , Average loss: 2.5312, Accuracy: 1009/10000 (10%)
#
# Train set, Epoch 69 [0/60000]	Loss: 2.127857
# Train Accuracy:  22.0
# Train set, Epoch 69 [50000/60000]	Loss: 2.064980
# Train Accuracy:  25.27
#
# Test set, Epoch 69 , Average loss: 2.5104, Accuracy: 1033/10000 (10%)
#
# Train set, Epoch 70 [0/60000]	Loss: 2.062749
# Train Accuracy:  25.0
# Train set, Epoch 70 [50000/60000]	Loss: 2.087375
# Train Accuracy:  25.38
#
# Test set, Epoch 70 , Average loss: 2.4919, Accuracy: 1104/10000 (11%)
#
# Train set, Epoch 71 [0/60000]	Loss: 2.075927
# Train Accuracy:  29.0
# Train set, Epoch 71 [50000/60000]	Loss: 2.116620
# Train Accuracy:  25.38
#
# Test set, Epoch 71 , Average loss: 2.4907, Accuracy: 1210/10000 (12%)
#
# Train set, Epoch 72 [0/60000]	Loss: 2.139248
# Train Accuracy:  23.0
# Train set, Epoch 72 [50000/60000]	Loss: 2.206208
# Train Accuracy:  25.56
#
# Test set, Epoch 72 , Average loss: 2.4987, Accuracy: 1094/10000 (11%)
#
# Train set, Epoch 73 [0/60000]	Loss: 2.040813
# Train Accuracy:  31.0
# Train set, Epoch 73 [50000/60000]	Loss: 2.112212
# Train Accuracy:  25.56
#
# Test set, Epoch 73 , Average loss: 2.5024, Accuracy: 1204/10000 (12%)
#
# Train set, Epoch 74 [0/60000]	Loss: 2.054133
# Train Accuracy:  26.0
# Train set, Epoch 74 [50000/60000]	Loss: 2.213830
# Train Accuracy:  25.76
#
# Test set, Epoch 74 , Average loss: 2.5272, Accuracy: 1026/10000 (10%)
#
# Train set, Epoch 75 [0/60000]	Loss: 2.095227
# Train Accuracy:  23.0
# Train set, Epoch 75 [50000/60000]	Loss: 2.059721
# Train Accuracy:  25.97
#
# Test set, Epoch 75 , Average loss: 2.4977, Accuracy: 1126/10000 (11%)
#
# Train set, Epoch 76 [0/60000]	Loss: 2.002155
# Train Accuracy:  36.0
# Train set, Epoch 76 [50000/60000]	Loss: 2.082875
# Train Accuracy:  26.22
#
# Test set, Epoch 76 , Average loss: 2.5199, Accuracy: 1094/10000 (11%)
#
# Train set, Epoch 77 [0/60000]	Loss: 2.062654
# Train Accuracy:  28.0
# Train set, Epoch 77 [50000/60000]	Loss: 2.035122
# Train Accuracy:  26.25
#
# Test set, Epoch 77 , Average loss: 2.5177, Accuracy: 1154/10000 (12%)
#
# Train set, Epoch 78 [0/60000]	Loss: 2.022039
# Train Accuracy:  30.0
# Train set, Epoch 78 [50000/60000]	Loss: 2.089725
# Train Accuracy:  26.49
#
# Test set, Epoch 78 , Average loss: 2.5087, Accuracy: 1217/10000 (12%)
#
# Train set, Epoch 79 [0/60000]	Loss: 2.060014
# Train Accuracy:  25.0
# Train set, Epoch 79 [50000/60000]	Loss: 2.107162
# Train Accuracy:  26.74
#
# Test set, Epoch 79 , Average loss: 2.5240, Accuracy: 1107/10000 (11%)
#
# Train set, Epoch 80 [0/60000]	Loss: 2.048437
# Train Accuracy:  32.0
# Train set, Epoch 80 [50000/60000]	Loss: 2.129139
# Train Accuracy:  26.77
#
# Test set, Epoch 80 , Average loss: 2.5389, Accuracy: 1094/10000 (11%)
#
# Train set, Epoch 81 [0/60000]	Loss: 2.059625
# Train Accuracy:  27.0
# Train set, Epoch 81 [50000/60000]	Loss: 1.977983
# Train Accuracy:  26.99
#
# Test set, Epoch 81 , Average loss: 2.5319, Accuracy: 1124/10000 (11%)
#
# Train set, Epoch 82 [0/60000]	Loss: 1.995044
# Train Accuracy:  28.0
# Train set, Epoch 82 [50000/60000]	Loss: 2.186896
# Train Accuracy:  27.2
#
# Test set, Epoch 82 , Average loss: 2.5101, Accuracy: 1187/10000 (12%)
#
# Train set, Epoch 83 [0/60000]	Loss: 2.021398
# Train Accuracy:  28.0
# Train set, Epoch 83 [50000/60000]	Loss: 2.051459
# Train Accuracy:  27.16
#
# Test set, Epoch 83 , Average loss: 2.5684, Accuracy: 975/10000 (10%)
#
# Train set, Epoch 84 [0/60000]	Loss: 1.960892
# Train Accuracy:  27.0
# Train set, Epoch 84 [50000/60000]	Loss: 2.099264
# Train Accuracy:  27.36
#
# Test set, Epoch 84 , Average loss: 2.5256, Accuracy: 1300/10000 (13%)
#
# Train set, Epoch 85 [0/60000]	Loss: 2.137637
# Train Accuracy:  25.0
# Train set, Epoch 85 [50000/60000]	Loss: 2.006928
# Train Accuracy:  27.54
#
# Test set, Epoch 85 , Average loss: 2.5340, Accuracy: 1107/10000 (11%)
#
# Train set, Epoch 86 [0/60000]	Loss: 2.003399
# Train Accuracy:  27.0
# Train set, Epoch 86 [50000/60000]	Loss: 1.887203
# Train Accuracy:  27.61
#
# Test set, Epoch 86 , Average loss: 2.5430, Accuracy: 1198/10000 (12%)
#
# Train set, Epoch 87 [0/60000]	Loss: 2.102798
# Train Accuracy:  21.0
# Train set, Epoch 87 [50000/60000]	Loss: 1.982303
# Train Accuracy:  27.75
#
# Test set, Epoch 87 , Average loss: 2.5068, Accuracy: 1280/10000 (13%)
#
# Train set, Epoch 88 [0/60000]	Loss: 1.978145
# Train Accuracy:  30.0
# Train set, Epoch 88 [50000/60000]	Loss: 2.088584
# Train Accuracy:  28.01
#
# Test set, Epoch 88 , Average loss: 2.5417, Accuracy: 1134/10000 (11%)
#
# Train set, Epoch 89 [0/60000]	Loss: 2.067390
# Train Accuracy:  26.0
# Train set, Epoch 89 [50000/60000]	Loss: 2.026514
# Train Accuracy:  28.0
#
# Test set, Epoch 89 , Average loss: 2.5406, Accuracy: 1198/10000 (12%)
#
# Train set, Epoch 90 [0/60000]	Loss: 2.048521
# Train Accuracy:  27.0
# Train set, Epoch 90 [50000/60000]	Loss: 2.019049
# Train Accuracy:  28.13
#
# Test set, Epoch 90 , Average loss: 2.5624, Accuracy: 1170/10000 (12%)
#
# Train set, Epoch 91 [0/60000]	Loss: 1.888402
# Train Accuracy:  30.0
# Train set, Epoch 91 [50000/60000]	Loss: 2.053107
# Train Accuracy:  28.62
#
# Test set, Epoch 91 , Average loss: 2.5737, Accuracy: 1080/10000 (11%)
#
# Train set, Epoch 92 [0/60000]	Loss: 2.050888
# Train Accuracy:  29.0
# Train set, Epoch 92 [50000/60000]	Loss: 2.085373
# Train Accuracy:  28.55
#
# Test set, Epoch 92 , Average loss: 2.5802, Accuracy: 1108/10000 (11%)
#
# Train set, Epoch 93 [0/60000]	Loss: 1.980036
# Train Accuracy:  33.0
# Train set, Epoch 93 [50000/60000]	Loss: 2.093529
# Train Accuracy:  28.48
#
# Test set, Epoch 93 , Average loss: 2.5863, Accuracy: 1067/10000 (11%)
#
# Train set, Epoch 94 [0/60000]	Loss: 1.931342
# Train Accuracy:  26.0
# Train set, Epoch 94 [50000/60000]	Loss: 2.096901
# Train Accuracy:  28.91
#
# Test set, Epoch 94 , Average loss: 2.5982, Accuracy: 1110/10000 (11%)
#
# Train set, Epoch 95 [0/60000]	Loss: 1.932390
# Train Accuracy:  27.0
# Train set, Epoch 95 [50000/60000]	Loss: 2.048388
# Train Accuracy:  28.96
#
# Test set, Epoch 95 , Average loss: 2.6485, Accuracy: 965/10000 (10%)
#
# Train set, Epoch 96 [0/60000]	Loss: 1.966039
# Train Accuracy:  34.0
# Train set, Epoch 96 [50000/60000]	Loss: 1.976468
# Train Accuracy:  29.13
#
# Test set, Epoch 96 , Average loss: 2.5888, Accuracy: 1104/10000 (11%)
#
# Train set, Epoch 97 [0/60000]	Loss: 2.101355
# Train Accuracy:  21.0
# Train set, Epoch 97 [50000/60000]	Loss: 2.010565
# Train Accuracy:  29.16
#
# Test set, Epoch 97 , Average loss: 2.5978, Accuracy: 1125/10000 (11%)
#
# Train set, Epoch 98 [0/60000]	Loss: 2.012779
# Train Accuracy:  26.0
# Train set, Epoch 98 [50000/60000]	Loss: 2.017618
# Train Accuracy:  29.41
#
# Test set, Epoch 98 , Average loss: 2.6025, Accuracy: 1069/10000 (11%)
#
# Train set, Epoch 99 [0/60000]	Loss: 1.995132
# Train Accuracy:  29.0
# Train set, Epoch 99 [50000/60000]	Loss: 1.890180
# Train Accuracy:  29.44
#
# Test set, Epoch 99 , Average loss: 2.5865, Accuracy: 1176/10000 (12%)
#
# Train set, Epoch 100 [0/60000]	Loss: 1.996124
# Train Accuracy:  31.0
# Train set, Epoch 100 [50000/60000]	Loss: 1.956860
# Train Accuracy:  29.78
#
# Test set, Epoch 100 , Average loss: 2.6277, Accuracy: 1034/10000 (10%)

# %%
temp_1 = []
for i in m1_train_loss_arr:
    temp_1.append(i.data.numpy().tolist())
temp_2 = []
for i in m1_test_loss_arr:
    temp_2.append(i.data.numpy().tolist())

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(0, 100, 1), temp_1, color = "r")
plt.plot(np.arange(0, 100, 1), temp_2, color = "g")
plt.title('Model Loss Comparision')
plt.legend(['Train Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
