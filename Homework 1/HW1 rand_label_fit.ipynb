# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
torch.manual_seed(1)

# %%
def load_data(train_batch_size, test_batch_size):
    # Fetch training data: total 60000 samples
        
    trainset = datasets.MNIST('data', train = True, download = False, 
                transform = transforms.Compose([
                transforms.Resize((32,32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    temp = torch.tensor(np.random.randint(0, 10, (len(trainset)),))
    trainset.targets = temp
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=train_batch_size, shuffle=True)

    testset = datasets.MNIST('data', train = False, 
                transform = transforms.Compose([
                transforms.Resize((32, 32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    test_loader = torch.utils.data.DataLoader(testset ,batch_size = test_batch_size, shuffle=True)

    return (train_loader, test_loader)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = self.fc3(x)
        return x

# %%
train_batch_size = 100
test_batch_size = 100
train_loader, test_loader = load_data(train_batch_size, test_batch_size)

# %%
def train(model, optimizer, train_loader):
    model.train()
    loss_fn = torch.nn.CrossEntropyLoss()
    correct = 0
    train_loss = 0
    counter = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        counter += 1
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.data

        pred = np.argmax(output.data, axis=1)
        correct += np.equal(pred, target.data).sum()
    
    train_loss /= counter
    acc = 100.0 * correct / len(train_loader.dataset)
    return train_loss, acc

# %%
def test(model, epoch, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    
    loss_fn = torch.nn.CrossEntropyLoss(size_average=False)

    for data, target in test_loader:
        data, target = Variable(data), Variable(target)
        
        output = model(data)
        loss = loss_fn(output, target)
        test_loss += loss.data

        pred = np.argmax(output.data, axis = 1)
        correct = correct + np.equal(pred, target.data).sum()

    # Print log
    test_loss /= len(test_loader.dataset)
    print('\nTest set, Epoch {} , Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch,
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss

# %%
model = CNN()

optimizer = optim.Adam(model.parameters(), lr=0.0001)
m1_train_loss_arr = []
m1_test_loss_arr = []

epochs = 100
log_interval = 500
for epoch in range(1, epochs + 1):
    tr_loss, acc = train(model, optimizer, train_loader)
    m1_train_loss_arr.append(tr_loss)
    loss_test = test(model, epoch, test_loader)
    m1_test_loss_arr.append(loss_test)
    print('Epoch: ', epoch)
    print('Loss= ', tr_loss)
# Out:
# C:\Users\nikhi\anaconda3\envs\deeplearning\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set, Epoch 1 , Average loss: 2.3024, Accuracy: 818/10000 (8%)
#
# Epoch:  1
# Loss=  tensor(2.3033)
#
# Test set, Epoch 2 , Average loss: 2.3013, Accuracy: 480/10000 (5%)
#
# Epoch:  2
# Loss=  tensor(2.3025)
#
# Test set, Epoch 3 , Average loss: 2.3032, Accuracy: 928/10000 (9%)
#
# Epoch:  3
# Loss=  tensor(2.3020)
#
# Test set, Epoch 4 , Average loss: 2.3033, Accuracy: 499/10000 (5%)
#
# Epoch:  4
# Loss=  tensor(2.3014)
#
# Test set, Epoch 5 , Average loss: 2.3028, Accuracy: 969/10000 (10%)
#
# Epoch:  5
# Loss=  tensor(2.3007)
#
# Test set, Epoch 6 , Average loss: 2.3101, Accuracy: 1189/10000 (12%)
#
# Epoch:  6
# Loss=  tensor(2.2998)
#
# Test set, Epoch 7 , Average loss: 2.3098, Accuracy: 920/10000 (9%)
#
# Epoch:  7
# Loss=  tensor(2.2986)
#
# Test set, Epoch 8 , Average loss: 2.3163, Accuracy: 760/10000 (8%)
#
# Epoch:  8
# Loss=  tensor(2.2972)
#
# Test set, Epoch 9 , Average loss: 2.3238, Accuracy: 644/10000 (6%)
#
# Epoch:  9
# Loss=  tensor(2.2957)
#
# Test set, Epoch 10 , Average loss: 2.3084, Accuracy: 974/10000 (10%)
#
# Epoch:  10
# Loss=  tensor(2.2938)
#
# Test set, Epoch 11 , Average loss: 2.3151, Accuracy: 1044/10000 (10%)
#
# Epoch:  11
# Loss=  tensor(2.2920)
#
# Test set, Epoch 12 , Average loss: 2.3251, Accuracy: 796/10000 (8%)
#
# Epoch:  12
# Loss=  tensor(2.2897)
#
# Test set, Epoch 13 , Average loss: 2.3260, Accuracy: 1026/10000 (10%)
#
# Epoch:  13
# Loss=  tensor(2.2873)
#
# Test set, Epoch 14 , Average loss: 2.3159, Accuracy: 957/10000 (10%)
#
# Epoch:  14
# Loss=  tensor(2.2848)
#
# Test set, Epoch 15 , Average loss: 2.3224, Accuracy: 885/10000 (9%)
#
# Epoch:  15
# Loss=  tensor(2.2824)
#
# Test set, Epoch 16 , Average loss: 2.3200, Accuracy: 865/10000 (9%)
#
# Epoch:  16
# Loss=  tensor(2.2797)
#
# Test set, Epoch 17 , Average loss: 2.3246, Accuracy: 831/10000 (8%)
#
# Epoch:  17
# Loss=  tensor(2.2768)
#
# Test set, Epoch 18 , Average loss: 2.3242, Accuracy: 841/10000 (8%)
#
# Epoch:  18
# Loss=  tensor(2.2736)
#
# Test set, Epoch 19 , Average loss: 2.3181, Accuracy: 1087/10000 (11%)
#
# Epoch:  19
# Loss=  tensor(2.2707)
#
# Test set, Epoch 20 , Average loss: 2.3597, Accuracy: 723/10000 (7%)
#
# Epoch:  20
# Loss=  tensor(2.2673)
#
# Test set, Epoch 21 , Average loss: 2.3222, Accuracy: 908/10000 (9%)
#
# Epoch:  21
# Loss=  tensor(2.2638)
#
# Test set, Epoch 22 , Average loss: 2.3350, Accuracy: 897/10000 (9%)
#
# Epoch:  22
# Loss=  tensor(2.2606)
#
# Test set, Epoch 23 , Average loss: 2.3365, Accuracy: 1054/10000 (11%)
#
# Epoch:  23
# Loss=  tensor(2.2570)
#
# Test set, Epoch 24 , Average loss: 2.3549, Accuracy: 931/10000 (9%)
#
# Epoch:  24
# Loss=  tensor(2.2535)
#
# Test set, Epoch 25 , Average loss: 2.3512, Accuracy: 833/10000 (8%)
#
# Epoch:  25
# Loss=  tensor(2.2505)
#
# Test set, Epoch 26 , Average loss: 2.3395, Accuracy: 1041/10000 (10%)
#
# Epoch:  26
# Loss=  tensor(2.2464)
#
# Test set, Epoch 27 , Average loss: 2.3436, Accuracy: 990/10000 (10%)
#
# Epoch:  27
# Loss=  tensor(2.2428)
#
# Test set, Epoch 28 , Average loss: 2.3575, Accuracy: 933/10000 (9%)
#
# Epoch:  28
# Loss=  tensor(2.2388)
#
# Test set, Epoch 29 , Average loss: 2.3514, Accuracy: 935/10000 (9%)
#
# Epoch:  29
# Loss=  tensor(2.2350)
#
# Test set, Epoch 30 , Average loss: 2.3400, Accuracy: 1074/10000 (11%)
#
# Epoch:  30
# Loss=  tensor(2.2320)
#
# Test set, Epoch 31 , Average loss: 2.3615, Accuracy: 892/10000 (9%)
#
# Epoch:  31
# Loss=  tensor(2.2281)
#
# Test set, Epoch 32 , Average loss: 2.3564, Accuracy: 960/10000 (10%)
#
# Epoch:  32
# Loss=  tensor(2.2240)
#
# Test set, Epoch 33 , Average loss: 2.3724, Accuracy: 931/10000 (9%)
#
# Epoch:  33
# Loss=  tensor(2.2193)
#
# Test set, Epoch 34 , Average loss: 2.3617, Accuracy: 1028/10000 (10%)
#
# Epoch:  34
# Loss=  tensor(2.2162)
#
# Test set, Epoch 35 , Average loss: 2.3497, Accuracy: 1088/10000 (11%)
#
# Epoch:  35
# Loss=  tensor(2.2128)
#
# Test set, Epoch 36 , Average loss: 2.3675, Accuracy: 941/10000 (9%)
#
# Epoch:  36
# Loss=  tensor(2.2084)
#
# Test set, Epoch 37 , Average loss: 2.3695, Accuracy: 951/10000 (10%)
#
# Epoch:  37
# Loss=  tensor(2.2044)
#
# Test set, Epoch 38 , Average loss: 2.3887, Accuracy: 929/10000 (9%)
#
# Epoch:  38
# Loss=  tensor(2.2001)
#
# Test set, Epoch 39 , Average loss: 2.3908, Accuracy: 1012/10000 (10%)
#
# Epoch:  39
# Loss=  tensor(2.1962)
#
# Test set, Epoch 40 , Average loss: 2.3897, Accuracy: 1040/10000 (10%)
#
# Epoch:  40
# Loss=  tensor(2.1920)
#
# Test set, Epoch 41 , Average loss: 2.4372, Accuracy: 765/10000 (8%)
#
# Epoch:  41
# Loss=  tensor(2.1891)
#
# Test set, Epoch 42 , Average loss: 2.3983, Accuracy: 957/10000 (10%)
#
# Epoch:  42
# Loss=  tensor(2.1842)
#
# Test set, Epoch 43 , Average loss: 2.3767, Accuracy: 992/10000 (10%)
#
# Epoch:  43
# Loss=  tensor(2.1801)
#
# Test set, Epoch 44 , Average loss: 2.4114, Accuracy: 944/10000 (9%)
#
# Epoch:  44
# Loss=  tensor(2.1765)
#
# Test set, Epoch 45 , Average loss: 2.4355, Accuracy: 825/10000 (8%)
#
# Epoch:  45
# Loss=  tensor(2.1721)
#
# Test set, Epoch 46 , Average loss: 2.4099, Accuracy: 932/10000 (9%)
#
# Epoch:  46
# Loss=  tensor(2.1688)
#
# Test set, Epoch 47 , Average loss: 2.4348, Accuracy: 867/10000 (9%)
#
# Epoch:  47
# Loss=  tensor(2.1646)
#
# Test set, Epoch 48 , Average loss: 2.4430, Accuracy: 830/10000 (8%)
#
# Epoch:  48
# Loss=  tensor(2.1601)
#
# Test set, Epoch 49 , Average loss: 2.4358, Accuracy: 898/10000 (9%)
#
# Epoch:  49
# Loss=  tensor(2.1559)
#
# Test set, Epoch 50 , Average loss: 2.4338, Accuracy: 936/10000 (9%)
#
# Epoch:  50
# Loss=  tensor(2.1519)
#
# Test set, Epoch 51 , Average loss: 2.4208, Accuracy: 986/10000 (10%)
#
# Epoch:  51
# Loss=  tensor(2.1493)
#
# Test set, Epoch 52 , Average loss: 2.4507, Accuracy: 824/10000 (8%)
#
# Epoch:  52
# Loss=  tensor(2.1439)
#
# Test set, Epoch 53 , Average loss: 2.3991, Accuracy: 1179/10000 (12%)
#
# Epoch:  53
# Loss=  tensor(2.1394)
#
# Test set, Epoch 54 , Average loss: 2.4773, Accuracy: 869/10000 (9%)
#
# Epoch:  54
# Loss=  tensor(2.1360)
#
# Test set, Epoch 55 , Average loss: 2.4821, Accuracy: 827/10000 (8%)
#
# Epoch:  55
# Loss=  tensor(2.1322)
#
# Test set, Epoch 56 , Average loss: 2.4682, Accuracy: 949/10000 (9%)
#
# Epoch:  56
# Loss=  tensor(2.1281)
#
# Test set, Epoch 57 , Average loss: 2.4644, Accuracy: 954/10000 (10%)
#
# Epoch:  57
# Loss=  tensor(2.1242)
#
# Test set, Epoch 58 , Average loss: 2.4750, Accuracy: 922/10000 (9%)
#
# Epoch:  58
# Loss=  tensor(2.1196)
#
# Test set, Epoch 59 , Average loss: 2.4436, Accuracy: 1019/10000 (10%)
#
# Epoch:  59
# Loss=  tensor(2.1156)
#
# Test set, Epoch 60 , Average loss: 2.5044, Accuracy: 834/10000 (8%)
#
# Epoch:  60
# Loss=  tensor(2.1119)
#
# Test set, Epoch 61 , Average loss: 2.4886, Accuracy: 966/10000 (10%)
#
# Epoch:  61
# Loss=  tensor(2.1081)
#
# Test set, Epoch 62 , Average loss: 2.4619, Accuracy: 1029/10000 (10%)
#
# Epoch:  62
# Loss=  tensor(2.1041)
#
# Test set, Epoch 63 , Average loss: 2.5085, Accuracy: 865/10000 (9%)
#
# Epoch:  63
# Loss=  tensor(2.0999)
#
# Test set, Epoch 64 , Average loss: 2.4818, Accuracy: 972/10000 (10%)
#
# Epoch:  64
# Loss=  tensor(2.0959)
#
# Test set, Epoch 65 , Average loss: 2.5236, Accuracy: 888/10000 (9%)
#
# Epoch:  65
# Loss=  tensor(2.0920)
#
# Test set, Epoch 66 , Average loss: 2.4840, Accuracy: 885/10000 (9%)
#
# Epoch:  66
# Loss=  tensor(2.0881)
#
# Test set, Epoch 67 , Average loss: 2.4867, Accuracy: 984/10000 (10%)
#
# Epoch:  67
# Loss=  tensor(2.0846)
#
# Test set, Epoch 68 , Average loss: 2.4976, Accuracy: 972/10000 (10%)
#
# Epoch:  68
# Loss=  tensor(2.0804)
#
# Test set, Epoch 69 , Average loss: 2.5412, Accuracy: 810/10000 (8%)
#
# Epoch:  69
# Loss=  tensor(2.0763)
#
# Test set, Epoch 70 , Average loss: 2.5116, Accuracy: 876/10000 (9%)
#
# Epoch:  70
# Loss=  tensor(2.0715)
#
# Test set, Epoch 71 , Average loss: 2.5093, Accuracy: 1032/10000 (10%)
#
# Epoch:  71
# Loss=  tensor(2.0686)
#
# Test set, Epoch 72 , Average loss: 2.5018, Accuracy: 1035/10000 (10%)
#
# Epoch:  72
# Loss=  tensor(2.0647)
#
# Test set, Epoch 73 , Average loss: 2.5623, Accuracy: 873/10000 (9%)
#
# Epoch:  73
# Loss=  tensor(2.0598)
#
# Test set, Epoch 74 , Average loss: 2.5175, Accuracy: 992/10000 (10%)
#
# Epoch:  74
# Loss=  tensor(2.0568)
#
# Test set, Epoch 75 , Average loss: 2.5460, Accuracy: 845/10000 (8%)
#
# Epoch:  75
# Loss=  tensor(2.0526)
#
# Test set, Epoch 76 , Average loss: 2.5854, Accuracy: 805/10000 (8%)
#
# Epoch:  76
# Loss=  tensor(2.0491)
#
# Test set, Epoch 77 , Average loss: 2.5956, Accuracy: 798/10000 (8%)
#
# Epoch:  77
# Loss=  tensor(2.0452)
#
# Test set, Epoch 78 , Average loss: 2.5497, Accuracy: 907/10000 (9%)
#
# Epoch:  78
# Loss=  tensor(2.0418)
#
# Test set, Epoch 79 , Average loss: 2.5750, Accuracy: 860/10000 (9%)
#
# Epoch:  79
# Loss=  tensor(2.0372)
#
# Test set, Epoch 80 , Average loss: 2.5375, Accuracy: 1127/10000 (11%)
#
# Epoch:  80
# Loss=  tensor(2.0340)
#
# Test set, Epoch 81 , Average loss: 2.6025, Accuracy: 888/10000 (9%)
#
# Epoch:  81
# Loss=  tensor(2.0315)
#
# Test set, Epoch 82 , Average loss: 2.5525, Accuracy: 1033/10000 (10%)
#
# Epoch:  82
# Loss=  tensor(2.0275)
#
# Test set, Epoch 83 , Average loss: 2.5772, Accuracy: 925/10000 (9%)
#
# Epoch:  83
# Loss=  tensor(2.0227)
#
# Test set, Epoch 84 , Average loss: 2.5538, Accuracy: 1088/10000 (11%)
#
# Epoch:  84
# Loss=  tensor(2.0197)
#
# Test set, Epoch 85 , Average loss: 2.6053, Accuracy: 967/10000 (10%)
#
# Epoch:  85
# Loss=  tensor(2.0154)
#
# Test set, Epoch 86 , Average loss: 2.6133, Accuracy: 889/10000 (9%)
#
# Epoch:  86
# Loss=  tensor(2.0107)
#
# Test set, Epoch 87 , Average loss: 2.6199, Accuracy: 882/10000 (9%)
#
# Epoch:  87
# Loss=  tensor(2.0079)
#
# Test set, Epoch 88 , Average loss: 2.6253, Accuracy: 886/10000 (9%)
#
# Epoch:  88
# Loss=  tensor(2.0048)
#
# Test set, Epoch 89 , Average loss: 2.5265, Accuracy: 1110/10000 (11%)
#
# Epoch:  89
# Loss=  tensor(1.9998)
#
# Test set, Epoch 90 , Average loss: 2.6019, Accuracy: 991/10000 (10%)
#
# Epoch:  90
# Loss=  tensor(1.9982)
#
# Test set, Epoch 91 , Average loss: 2.6269, Accuracy: 882/10000 (9%)
#
# Epoch:  91
# Loss=  tensor(1.9931)
#
# Test set, Epoch 92 , Average loss: 2.6378, Accuracy: 888/10000 (9%)
#
# Epoch:  92
# Loss=  tensor(1.9902)
#
# Test set, Epoch 93 , Average loss: 2.6767, Accuracy: 777/10000 (8%)
#
# Epoch:  93
# Loss=  tensor(1.9860)
#
# Test set, Epoch 94 , Average loss: 2.6328, Accuracy: 923/10000 (9%)
#
# Epoch:  94
# Loss=  tensor(1.9831)
#
# Test set, Epoch 95 , Average loss: 2.6329, Accuracy: 959/10000 (10%)
#
# Epoch:  95
# Loss=  tensor(1.9791)
#
# Test set, Epoch 96 , Average loss: 2.6423, Accuracy: 866/10000 (9%)
#
# Epoch:  96
# Loss=  tensor(1.9759)
#
# Test set, Epoch 97 , Average loss: 2.6499, Accuracy: 938/10000 (9%)
#
# Epoch:  97
# Loss=  tensor(1.9729)
#
# Test set, Epoch 98 , Average loss: 2.6822, Accuracy: 887/10000 (9%)
#
# Epoch:  98
# Loss=  tensor(1.9686)
#
# Test set, Epoch 99 , Average loss: 2.7093, Accuracy: 826/10000 (8%)
#
# Epoch:  99
# Loss=  tensor(1.9654)
#
# Test set, Epoch 100 , Average loss: 2.6781, Accuracy: 907/10000 (9%)
#
# Epoch:  100
# Loss=  tensor(1.9618)

# %%
temp_1 = []
for i in m1_train_loss_arr:
    temp_1.append(i.data.numpy().tolist())
temp_2 = []
for i in m1_test_loss_arr:
    temp_2.append(i.data.numpy().tolist())

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(0, 100, 1), temp_1, color = "r")
plt.plot(np.arange(0, 100, 1), temp_2, color = "g")
plt.title('Model Loss Comparision')
plt.legend(['Train Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
