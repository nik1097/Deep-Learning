# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.manual_seed(1)

# %%
def load_data(train_batch_size, test_batch_size):
    # Fetch training data: total 60000 samples
    train_loader = torch.utils.data.DataLoader(
        datasets.MNIST('data', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.Resize((32, 32)),
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=train_batch_size, shuffle=True)

    # Fetch test data: total 10000 samples
    test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('data', train=False, transform=transforms.Compose([
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))
        ])),
        batch_size=test_batch_size, shuffle=True)

    return (train_loader, test_loader)

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = self.fc3(x)
        return x

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 5)
        self.conv2 = nn.Conv2d(32, 32, 5)
        self.conv3 = nn.Conv2d(32, 64, 5)
        self.fc1 = nn.Linear(1024, 256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(F.max_pool2d(self.conv3(x),2))
        x = F.dropout(x, p=0.5, training=self.training)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
train_batch_size = 64
test_batch_size = 1000
train_loader, test_loader = load_data(train_batch_size, test_batch_size)

# %%
def train(model, optimizer, epoch, train_loader, log_interval):
    model.train()
    loss_fn = torch.nn.CrossEntropyLoss()
    n_correct = 0
    n_samples = 0

    for batch_idx, (data, target) in enumerate(train_loader):

        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()

        optimizer.step()

        _, predicted = torch.max(output.data, 1)
        n_samples += target.size(0)
        n_correct += (predicted == target).sum().item()
        acc = 100.0 * n_correct / n_samples

        # print log
        if batch_idx % log_interval == 0:
            print('Train set, Epoch {} [{}/{}]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                loss.data))
            print("Train Accuracy: ", round(acc,2))
    return loss.data, round(acc,2)

# %%
def test(model, epoch, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    
    loss_fn = torch.nn.CrossEntropyLoss(size_average=False)

    for data, target in test_loader:
        data, target = Variable(data), Variable(target)
        
        output = model(data)
        test_loss += loss_fn(output, target).data

        pred = np.argmax(output.data, axis=1)
        correct = correct + np.equal(pred, target.data).sum()

    # Print log
    test_loss /= len(test_loader.dataset)
    print('\nTest set, Epoch {} , Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch,
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
torch.manual_seed(1)
model= LeNet()

lr = 0.01
momentum=0.5
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
m0_loss_arr = []
m0_acc_arr = []

epochs = 10
log_interval = 200
for epoch in range(1, epochs + 1):
    loss, acc = train(model, optimizer, epoch, train_loader, log_interval=log_interval)
    m0_loss_arr.append(loss)
    m0_acc_arr.append(acc)
    test(model, epoch, test_loader)
# Out:
# Train set, Epoch 1 [0/60000]	Loss: 2.322259
# Train Accuracy:  10.94
# Train set, Epoch 1 [12800/60000]	Loss: 0.390230
# Train Accuracy:  46.47
# Train set, Epoch 1 [25600/60000]	Loss: 0.319172
# Train Accuracy:  66.1
# Train set, Epoch 1 [38400/60000]	Loss: 0.246266
# Train Accuracy:  74.58
# Train set, Epoch 1 [51200/60000]	Loss: 0.253310
# Train Accuracy:  79.35
# C:\Users\nikhi\anaconda3\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set, Epoch 1 , Average loss: 0.1383, Accuracy: 9579/10000 (96%)
#
# Train set, Epoch 2 [0/60000]	Loss: 0.160365
# Train Accuracy:  93.75
# Train set, Epoch 2 [12800/60000]	Loss: 0.131775
# Train Accuracy:  95.36
# Train set, Epoch 2 [25600/60000]	Loss: 0.367226
# Train Accuracy:  95.66
# Train set, Epoch 2 [38400/60000]	Loss: 0.088492
# Train Accuracy:  95.93
# Train set, Epoch 2 [51200/60000]	Loss: 0.110210
# Train Accuracy:  96.14
#
# Test set, Epoch 2 , Average loss: 0.0779, Accuracy: 9757/10000 (98%)
#
# Train set, Epoch 3 [0/60000]	Loss: 0.025955
# Train Accuracy:  100.0
# Train set, Epoch 3 [12800/60000]	Loss: 0.077219
# Train Accuracy:  97.33
# Train set, Epoch 3 [25600/60000]	Loss: 0.046184
# Train Accuracy:  97.32
# Train set, Epoch 3 [38400/60000]	Loss: 0.036248
# Train Accuracy:  97.41
# Train set, Epoch 3 [51200/60000]	Loss: 0.069871
# Train Accuracy:  97.42
#
# Test set, Epoch 3 , Average loss: 0.0685, Accuracy: 9776/10000 (98%)
#
# Train set, Epoch 4 [0/60000]	Loss: 0.120706
# Train Accuracy:  98.44
# Train set, Epoch 4 [12800/60000]	Loss: 0.138659
# Train Accuracy:  98.03
# Train set, Epoch 4 [25600/60000]	Loss: 0.081395
# Train Accuracy:  98.07
# Train set, Epoch 4 [38400/60000]	Loss: 0.193834
# Train Accuracy:  98.1
# Train set, Epoch 4 [51200/60000]	Loss: 0.084824
# Train Accuracy:  98.09
#
# Test set, Epoch 4 , Average loss: 0.0510, Accuracy: 9836/10000 (98%)
#
# Train set, Epoch 5 [0/60000]	Loss: 0.013658
# Train Accuracy:  100.0
# Train set, Epoch 5 [12800/60000]	Loss: 0.027942
# Train Accuracy:  98.48
# Train set, Epoch 5 [25600/60000]	Loss: 0.080717
# Train Accuracy:  98.43
# Train set, Epoch 5 [38400/60000]	Loss: 0.006031
# Train Accuracy:  98.43
# Train set, Epoch 5 [51200/60000]	Loss: 0.012109
# Train Accuracy:  98.41
#
# Test set, Epoch 5 , Average loss: 0.0478, Accuracy: 9840/10000 (98%)
#
# Train set, Epoch 6 [0/60000]	Loss: 0.047291
# Train Accuracy:  98.44
# Train set, Epoch 6 [12800/60000]	Loss: 0.092299
# Train Accuracy:  98.74
# Train set, Epoch 6 [25600/60000]	Loss: 0.016910
# Train Accuracy:  98.72
# Train set, Epoch 6 [38400/60000]	Loss: 0.012798
# Train Accuracy:  98.65
# Train set, Epoch 6 [51200/60000]	Loss: 0.081852
# Train Accuracy:  98.65
#
# Test set, Epoch 6 , Average loss: 0.0409, Accuracy: 9872/10000 (99%)
#
# Train set, Epoch 7 [0/60000]	Loss: 0.053126
# Train Accuracy:  96.88
# Train set, Epoch 7 [12800/60000]	Loss: 0.027499
# Train Accuracy:  98.84
# Train set, Epoch 7 [25600/60000]	Loss: 0.031999
# Train Accuracy:  98.79
# Train set, Epoch 7 [38400/60000]	Loss: 0.015569
# Train Accuracy:  98.7
# Train set, Epoch 7 [51200/60000]	Loss: 0.004786
# Train Accuracy:  98.73
#
# Test set, Epoch 7 , Average loss: 0.0397, Accuracy: 9877/10000 (99%)
#
# Train set, Epoch 8 [0/60000]	Loss: 0.037117
# Train Accuracy:  98.44
# Train set, Epoch 8 [12800/60000]	Loss: 0.005358
# Train Accuracy:  98.9
# Train set, Epoch 8 [25600/60000]	Loss: 0.017643
# Train Accuracy:  98.86
# Train set, Epoch 8 [38400/60000]	Loss: 0.067330
# Train Accuracy:  98.84
# Train set, Epoch 8 [51200/60000]	Loss: 0.018616
# Train Accuracy:  98.83
#
# Test set, Epoch 8 , Average loss: 0.0368, Accuracy: 9889/10000 (99%)
#
# Train set, Epoch 9 [0/60000]	Loss: 0.004393
# Train Accuracy:  100.0
# Train set, Epoch 9 [12800/60000]	Loss: 0.001756
# Train Accuracy:  99.16
# Train set, Epoch 9 [25600/60000]	Loss: 0.023638
# Train Accuracy:  99.13
# Train set, Epoch 9 [38400/60000]	Loss: 0.022182
# Train Accuracy:  99.04
# Train set, Epoch 9 [51200/60000]	Loss: 0.003377
# Train Accuracy:  99.03
#
# Test set, Epoch 9 , Average loss: 0.0404, Accuracy: 9874/10000 (99%)
#
# Train set, Epoch 10 [0/60000]	Loss: 0.002629
# Train Accuracy:  100.0
# Train set, Epoch 10 [12800/60000]	Loss: 0.009293
# Train Accuracy:  99.13
# Train set, Epoch 10 [25600/60000]	Loss: 0.005835
# Train Accuracy:  99.15
# Train set, Epoch 10 [38400/60000]	Loss: 0.002532
# Train Accuracy:  99.14
# Train set, Epoch 10 [51200/60000]	Loss: 0.011232
# Train Accuracy:  99.11
#
# Test set, Epoch 10 , Average loss: 0.0413, Accuracy: 9870/10000 (99%)

# %%
torch.manual_seed(1)

model_1= CNN()

lr = 0.01
momentum = 0.5
optimizer = optim.SGD(model_1.parameters(), lr=lr, momentum=momentum)
m1_loss_arr = []
m1_acc_arr = []

epochs = 10
log_interval = 100
for epoch in range(1, epochs + 1):
    loss, acc = train(model_1, optimizer, epoch, train_loader, log_interval=log_interval)
    m1_loss_arr.append(loss)
    m1_acc_arr.append(acc)
    test(model_1, epoch, test_loader)
# Out:
# Train set, Epoch 1 [0/60000]	Loss: 2.315159
# Train Accuracy:  6.25
# Train set, Epoch 1 [6400/60000]	Loss: 1.535422
# Train Accuracy:  24.49
# Train set, Epoch 1 [12800/60000]	Loss: 0.935279
# Train Accuracy:  45.8
# Train set, Epoch 1 [19200/60000]	Loss: 0.400502
# Train Accuracy:  57.51
# Train set, Epoch 1 [25600/60000]	Loss: 0.404569
# Train Accuracy:  64.57
# Train set, Epoch 1 [32000/60000]	Loss: 0.294321
# Train Accuracy:  69.02
# Train set, Epoch 1 [38400/60000]	Loss: 0.378723
# Train Accuracy:  72.34
# Train set, Epoch 1 [44800/60000]	Loss: 0.295380
# Train Accuracy:  74.95
# Train set, Epoch 1 [51200/60000]	Loss: 0.281583
# Train Accuracy:  76.96
# Train set, Epoch 1 [57600/60000]	Loss: 0.492485
# Train Accuracy:  78.64
#
# Test set, Epoch 1 , Average loss: 0.1213, Accuracy: 9629/10000 (96%)
#
# Train set, Epoch 2 [0/60000]	Loss: 0.278653
# Train Accuracy:  93.75
# Train set, Epoch 2 [6400/60000]	Loss: 0.204269
# Train Accuracy:  93.18
# Train set, Epoch 2 [12800/60000]	Loss: 0.149855
# Train Accuracy:  93.17
# Train set, Epoch 2 [19200/60000]	Loss: 0.172114
# Train Accuracy:  93.32
# Train set, Epoch 2 [25600/60000]	Loss: 0.154698
# Train Accuracy:  93.5
# Train set, Epoch 2 [32000/60000]	Loss: 0.159759
# Train Accuracy:  93.64
# Train set, Epoch 2 [38400/60000]	Loss: 0.314004
# Train Accuracy:  93.78
# Train set, Epoch 2 [44800/60000]	Loss: 0.291373
# Train Accuracy:  93.87
# Train set, Epoch 2 [51200/60000]	Loss: 0.153167
# Train Accuracy:  93.97
# Train set, Epoch 2 [57600/60000]	Loss: 0.094409
# Train Accuracy:  94.09
#
# Test set, Epoch 2 , Average loss: 0.0715, Accuracy: 9778/10000 (98%)
#
# Train set, Epoch 3 [0/60000]	Loss: 0.080507
# Train Accuracy:  96.88
# Train set, Epoch 3 [6400/60000]	Loss: 0.169529
# Train Accuracy:  95.11
# Train set, Epoch 3 [12800/60000]	Loss: 0.132921
# Train Accuracy:  95.31
# Train set, Epoch 3 [19200/60000]	Loss: 0.230306
# Train Accuracy:  95.35
# Train set, Epoch 3 [25600/60000]	Loss: 0.078550
# Train Accuracy:  95.41
# Train set, Epoch 3 [32000/60000]	Loss: 0.153411
# Train Accuracy:  95.42
# Train set, Epoch 3 [38400/60000]	Loss: 0.112446
# Train Accuracy:  95.43
# Train set, Epoch 3 [44800/60000]	Loss: 0.283970
# Train Accuracy:  95.56
# Train set, Epoch 3 [51200/60000]	Loss: 0.090535
# Train Accuracy:  95.64
# Train set, Epoch 3 [57600/60000]	Loss: 0.287872
# Train Accuracy:  95.7
#
# Test set, Epoch 3 , Average loss: 0.0528, Accuracy: 9845/10000 (98%)
#
# Train set, Epoch 4 [0/60000]	Loss: 0.025708
# Train Accuracy:  100.0
# Train set, Epoch 4 [6400/60000]	Loss: 0.130174
# Train Accuracy:  96.1
# Train set, Epoch 4 [12800/60000]	Loss: 0.275280
# Train Accuracy:  96.27
# Train set, Epoch 4 [19200/60000]	Loss: 0.033743
# Train Accuracy:  96.38
# Train set, Epoch 4 [25600/60000]	Loss: 0.074238
# Train Accuracy:  96.36
# Train set, Epoch 4 [32000/60000]	Loss: 0.199017
# Train Accuracy:  96.42
# Train set, Epoch 4 [38400/60000]	Loss: 0.098382
# Train Accuracy:  96.37
# Train set, Epoch 4 [44800/60000]	Loss: 0.256032
# Train Accuracy:  96.4
# Train set, Epoch 4 [51200/60000]	Loss: 0.194309
# Train Accuracy:  96.47
# Train set, Epoch 4 [57600/60000]	Loss: 0.269744
# Train Accuracy:  96.53
#
# Test set, Epoch 4 , Average loss: 0.0430, Accuracy: 9867/10000 (99%)
#
# Train set, Epoch 5 [0/60000]	Loss: 0.114513
# Train Accuracy:  95.31
# Train set, Epoch 5 [6400/60000]	Loss: 0.054026
# Train Accuracy:  96.91
# Train set, Epoch 5 [12800/60000]	Loss: 0.093272
# Train Accuracy:  97.01
# Train set, Epoch 5 [19200/60000]	Loss: 0.066066
# Train Accuracy:  97.03
# Train set, Epoch 5 [25600/60000]	Loss: 0.009704
# Train Accuracy:  97.05
# Train set, Epoch 5 [32000/60000]	Loss: 0.010804
# Train Accuracy:  96.95
# Train set, Epoch 5 [38400/60000]	Loss: 0.038504
# Train Accuracy:  96.95
# Train set, Epoch 5 [44800/60000]	Loss: 0.149123
# Train Accuracy:  96.96
# Train set, Epoch 5 [51200/60000]	Loss: 0.090098
# Train Accuracy:  96.97
# Train set, Epoch 5 [57600/60000]	Loss: 0.065737
# Train Accuracy:  97.0
#
# Test set, Epoch 5 , Average loss: 0.0404, Accuracy: 9879/10000 (99%)
#
# Train set, Epoch 6 [0/60000]	Loss: 0.145282
# Train Accuracy:  95.31
# Train set, Epoch 6 [6400/60000]	Loss: 0.067937
# Train Accuracy:  97.22
# Train set, Epoch 6 [12800/60000]	Loss: 0.208921
# Train Accuracy:  97.11
# Train set, Epoch 6 [19200/60000]	Loss: 0.054621
# Train Accuracy:  97.2
# Train set, Epoch 6 [25600/60000]	Loss: 0.149919
# Train Accuracy:  97.21
# Train set, Epoch 6 [32000/60000]	Loss: 0.050299
# Train Accuracy:  97.22
# Train set, Epoch 6 [38400/60000]	Loss: 0.054990
# Train Accuracy:  97.29
# Train set, Epoch 6 [44800/60000]	Loss: 0.168843
# Train Accuracy:  97.33
# Train set, Epoch 6 [51200/60000]	Loss: 0.104749
# Train Accuracy:  97.33
# Train set, Epoch 6 [57600/60000]	Loss: 0.092126
# Train Accuracy:  97.33
#
# Test set, Epoch 6 , Average loss: 0.0370, Accuracy: 9889/10000 (99%)
#
# Train set, Epoch 7 [0/60000]	Loss: 0.082958
# Train Accuracy:  96.88
# Train set, Epoch 7 [6400/60000]	Loss: 0.079063
# Train Accuracy:  97.56
# Train set, Epoch 7 [12800/60000]	Loss: 0.104317
# Train Accuracy:  97.51
# Train set, Epoch 7 [19200/60000]	Loss: 0.084054
# Train Accuracy:  97.57
# Train set, Epoch 7 [25600/60000]	Loss: 0.086129
# Train Accuracy:  97.66
# Train set, Epoch 7 [32000/60000]	Loss: 0.203663
# Train Accuracy:  97.64
# Train set, Epoch 7 [38400/60000]	Loss: 0.020266
# Train Accuracy:  97.61
# Train set, Epoch 7 [44800/60000]	Loss: 0.008371
# Train Accuracy:  97.59
# Train set, Epoch 7 [51200/60000]	Loss: 0.082992
# Train Accuracy:  97.59
# Train set, Epoch 7 [57600/60000]	Loss: 0.118232
# Train Accuracy:  97.6
#
# Test set, Epoch 7 , Average loss: 0.0308, Accuracy: 9903/10000 (99%)
#
# Train set, Epoch 8 [0/60000]	Loss: 0.146268
# Train Accuracy:  95.31
# Train set, Epoch 8 [6400/60000]	Loss: 0.105474
# Train Accuracy:  97.79
# Train set, Epoch 8 [12800/60000]	Loss: 0.136318
# Train Accuracy:  97.77
# Train set, Epoch 8 [19200/60000]	Loss: 0.012931
# Train Accuracy:  97.78
# Train set, Epoch 8 [25600/60000]	Loss: 0.039661
# Train Accuracy:  97.74
# Train set, Epoch 8 [32000/60000]	Loss: 0.071243
# Train Accuracy:  97.7
# Train set, Epoch 8 [38400/60000]	Loss: 0.002145
# Train Accuracy:  97.74
# Train set, Epoch 8 [44800/60000]	Loss: 0.040815
# Train Accuracy:  97.76
# Train set, Epoch 8 [51200/60000]	Loss: 0.040869
# Train Accuracy:  97.76
# Train set, Epoch 8 [57600/60000]	Loss: 0.077442
# Train Accuracy:  97.79
#
# Test set, Epoch 8 , Average loss: 0.0282, Accuracy: 9912/10000 (99%)
#
# Train set, Epoch 9 [0/60000]	Loss: 0.021723
# Train Accuracy:  100.0
# Train set, Epoch 9 [6400/60000]	Loss: 0.149213
# Train Accuracy:  97.74
# Train set, Epoch 9 [12800/60000]	Loss: 0.087921
# Train Accuracy:  97.71
# Train set, Epoch 9 [19200/60000]	Loss: 0.085004
# Train Accuracy:  97.66
# Train set, Epoch 9 [25600/60000]	Loss: 0.054484
# Train Accuracy:  97.75
# Train set, Epoch 9 [32000/60000]	Loss: 0.019054
# Train Accuracy:  97.81
# Train set, Epoch 9 [38400/60000]	Loss: 0.024537
# Train Accuracy:  97.8
# Train set, Epoch 9 [44800/60000]	Loss: 0.100692
# Train Accuracy:  97.82
# Train set, Epoch 9 [51200/60000]	Loss: 0.023441
# Train Accuracy:  97.83
# Train set, Epoch 9 [57600/60000]	Loss: 0.092464
# Train Accuracy:  97.87
#
# Test set, Epoch 9 , Average loss: 0.0261, Accuracy: 9932/10000 (99%)
#
# Train set, Epoch 10 [0/60000]	Loss: 0.076828
# Train Accuracy:  96.88
# Train set, Epoch 10 [6400/60000]	Loss: 0.010214
# Train Accuracy:  97.74
# Train set, Epoch 10 [12800/60000]	Loss: 0.021251
# Train Accuracy:  97.94
# Train set, Epoch 10 [19200/60000]	Loss: 0.012233
# Train Accuracy:  98.0
# Train set, Epoch 10 [25600/60000]	Loss: 0.188500
# Train Accuracy:  97.95
# Train set, Epoch 10 [32000/60000]	Loss: 0.066666
# Train Accuracy:  97.98
# Train set, Epoch 10 [38400/60000]	Loss: 0.087035
# Train Accuracy:  98.02
# Train set, Epoch 10 [44800/60000]	Loss: 0.051889
# Train Accuracy:  98.02
# Train set, Epoch 10 [51200/60000]	Loss: 0.118280
# Train Accuracy:  98.0
# Train set, Epoch 10 [57600/60000]	Loss: 0.103301
# Train Accuracy:  97.99
#
# Test set, Epoch 10 , Average loss: 0.0247, Accuracy: 9931/10000 (99%)

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(1, 11, 1), m0_loss_arr, color = "r")
plt.plot(np.arange(1, 11, 1), m1_loss_arr, color = "g")
plt.title('Model Loss')
plt.legend(['Model 1', 'Model 2'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(1, 11, 1), m0_acc_arr, color = "r")
plt.plot(np.arange(1, 11, 1), m1_acc_arr, color = "g")
plt.title('Model Accuracy')
plt.legend(['Model 1', 'Model 2'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()
